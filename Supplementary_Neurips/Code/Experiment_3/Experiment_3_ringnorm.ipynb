# %%
import numpy as np
from numpy import genfromtxt
from sklearn import svm
from sklearn.metrics import accuracy_score
import random
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
import numpy.linalg as la
import scipy.io as sio
import pickle
from cvxopt import matrix, solvers
from sklearn.decomposition import PCA,KernelPCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# We implement all of the methods using a V-matrix framework. Note that for all previous methods, the V-matrix is diagonal. This is because all previous methods assign an importance or weight to each point, whose lose is signified by the diagonal. Our contribution is to use Vapnik's framework, which utilizes the entire matrix. Kleip is run on the original Matlab code and the weights are imported.

# %%
def V_matrix_Huang(T,X,n_t,sig=0.1):
  l = X.shape[0]
  m = T.shape[0]
  V = np.identity(l)
  P = matrix(gram_matrix(X,sig))
  K = Kernel.gaussian(sig)
  sum_T = [0 for i in range(l)]
  for i in range(l):
    for t in range(m):
      sum_T[i]+=K(T[t],X[i])
    sum_T[i] = -1*l/m*sum_T[i]  
  q = matrix(sum_T)
  G = [[0]*l for i in range(2*l+2)]
  for i in range(l):
    G[i][i] = 1
    G[i+1][i] = -1
  for j in range(l):
    G[2*l][j] = 1
    G[2*l+1][j] = -1
 
  G = matrix(np.array(G),tc ='d')
  B = 1000
  eps = 1-1/np.sqrt(l)
  h = [0 for i in range(2*l+2)]
  for i in range(l):
    h[i] = B
  h[2*l] = l+l*eps
  h[2*l+1] = max(l-l*eps,0)  
  h = matrix(h)
  solvers.options['show_progress'] = False
  sol = solvers.qp(P,q,G,h)
  solution = np.array(sol['x'])
  diagonal = [solution[i][0] for i in range(l)]
  V = np.diag(diagonal)
  return V 

def V_matrix_new(T,X,n_t):
  l = X.shape[0]
  V = np.identity(l) # our V
  for i in range(l):
    for j in range(l):
      V[i,j] = 0
      for t in T:
        u = 1
        for d in range(T.shape[1]):
          if t[d] < np.maximum(X[i,d],X[j,d]):
            u = 0
            break
        V[i,j]+=u  
      V[i,j] = V[i,j]/n_t 
  #P,Q,R = la.svd(V)
  #Q_hat = np.diag([Q[i] + .01 for i in range(l)])
  #V = np.matmul(np.matmul(P,Q_hat),R) #Regularizing V in high dimensions     
  return V
def V_matrix_new_2(T,X,n_t):
  l = X.shape[0]
  V = np.identity(l) # our V
  for i in range(l):
    for j in range(l):
      V[i,j] = 1
      for d in range(T.shape[1]):
        u = 0
        for t in T:
          if t[d] >= np.maximum(X[i,d],X[j,d]):
            u+= 1
        u = u/n_t
        V[i,j]*=u  
      #V[i,j] = V[i,j]/n_t 
  #P,Q,R = la.svd(V)
  #Q_hat = np.diag([Q[i] + .01 for i in range(l)])
  #V = np.matmul(np.matmul(P,Q_hat),R) #Regularizing V in high dimensions     
  return V

def V_matrix_LDA(T, X, n_t, lda):
  X_r = lda.transform(X)
  T_r = lda.transform(T)

  l = X.shape[0]
  V = np.identity(l) # our V
  for i in range(l):
    for j in range(l):
      V[i,j] = 0
      for t in T_r:
        u = 1
        for d in range(T_r.shape[1]):
          if t[d] < np.maximum(X_r[i,d],X_r[j,d]):
            u = 0
            break
        V[i,j]+=u    
      V[i,j] = V[i,j]/n_t 
  #P,Q,R = la.svd(V)
  #Q_hat = np.diag([Q[i] for i in range(l)])
  #V = np.matmul(np.matmul(P,Q_hat),R) #Regularizing V in high dimensions     
  return V



def V_matrix_add(T,X,n_t):
  l = X.shape[0]
  V = np.identity(l) # our V
  for i in range(l):
    for j in range(l):
      V[i,j] = 0
      for t in T:
        u = 0
        for d in range(T.shape[1]):
          if t[d] >= np.maximum(X[i,d],X[j,d]):
            u += 1
        V[i,j]+=u/T.shape[1]    
      V[i,j] = V[i,j]/n_t 
  #P,Q,R = la.svd(V)
  #Q_hat = np.diag([Q[i] for i in range(l)])
  #V = np.matmul(np.matmul(P,Q_hat),R) #Regularizing V in high dimensions     
  return V

def Vapnik(X):
  l = X.shape[0]
  V = np.array([[1]*l for i in range(l)]) 
  for i in range(l):
    for j in range(l):
      for d in range(X.shape[1]):
        V[i,j]+= 1-np.maximum(X[i,d],X[j,d])
  P,Q,R = la.svd(V)
  #Q_hat = np.diag([Q[i]+0.001 for i in range(l)])
  #V = np.matmul(np.matmul(P,Q_hat),R) #Regularizing V in high dimensions 
  return V

def unif_kernel(x,X,h):
  n = X.shape[0]
  val = 0
  for i in range(n):
    if la.norm((x-X[i])/h,1) <=1:
      val+= 0.5  
  q = val/(n*h)
  return q

def gauss_kernel(x,X,h):
  n = X.shape[0]
  val = 0
  for i in range(n):
    val+=1/(np.sqrt(2*np.pi))*(np.exp(-la.norm((x-X[i])/h)**2/2))
  q = val/(n*h)
  return q

def V_matrix_Shimodaira(T,X,n_t,h):
  l = X.shape[0]
  V = np.identity(l)
  for i in range(l):
    l_1 = gauss_kernel(X[i],T,h)
    l_0 = gauss_kernel(X[i],X,h)
    V[i,i] = l_1/l_0
  return V

def V_matrix_Sugiyama(T,X,n_t,h,tau):
  l = X.shape[0]
  V = np.identity(l)
  for i in range(l):
    l_1 = gauss_kernel(X[i],T,h)
    l_0 = gauss_kernel(X[i],X,h)
    V[i,i] = (l_1/l_0)**tau
  return V

def V_matrix_Makoto(T,X,n_t,h,a):
  l = X.shape[0]
  V = np.identity(l)
  for i in range(l):
    l_1 = gauss_kernel(X[i],T,h)
    l_0 = gauss_kernel(X[i],X,h)
    V[i,i] = l_1/(a*l_0+(1-a)*l_1)
  return V  

def test_methods_review(T,X,Y,Y_test,V):
  U = gram_matrix(X)# get the gram matrix for the given training set X
  g = 0.1  
  A, c = A_estimate(V,U,Y,g)
  p = []
  p_exp = Y_test
  for t in range(T.shape[0]):
    U_l = style_K(X,T[t]) #U_l = # kernel for the test set
    p.append(p_estimate(A,c,U_l))
  p = np.array(p)
  e = la.norm(p_exp-p)**2/T.shape[0]
  return e


#Estimate of A and c
def A_estimate(V,U,Y,g):
  l = V.shape[0]
  I = np.identity(l)
  O = np.ones((l,1))
  a_1 = np.matmul(V,U)
  a_2 = np.matmul(V,Y.reshape(l,1))
  a_3 = np.matmul(V,O)
  W = np.linalg.inv(a_1+g*I) # g:regularization constant
  A_b = np.matmul(W,a_2).reshape(l,1) # from equation 14
  A_c = np.matmul(W,a_3).reshape(l,1) # from equation 14
  c_1 = np.matmul(O.transpose(),np.matmul(a_1,A_b)-a_2) # numerator in equation 14
  c_2 = np.matmul(O.transpose(),np.matmul(a_1,A_c)-a_3)# denominator in equation 14
  c = c_1/c_2 # from equation 14
  A = A_b - c[0,0]*A_c
  return A,c

#Conditional probability estimate for a given x
def p_estimate(A,c,U_l):
  p = np.matmul(A.transpose(),U_l)+c
  if p[0,0] > 0.5:
    return 1
  else:
    return 0  

def gram_matrix(X,sig = 0.1):
   l = X.shape[0]
   U = np.zeros((l,l))
   K = Kernel.gaussian(sig)         
   for i in range(l):
     for j in range(l):
       U[i,j] = K(X[i],X[j])
   return U

def style_K(X,t):
   l = X.shape[0]
   U_l = np.zeros((l,1))
   K = Kernel.gaussian(.1)
   for i in range(l):
     U_l[i] = K(t,X[i])    
   return U_l  

class Kernel(object):
    """Implements list of kernels from
    http://en.wikipedia.org/wiki/Support_vector_machine
    """
    @staticmethod
    def linear():
        def f(x, y):
            return np.inner(x, y)
        return f

    @staticmethod
    def gaussian(sigma):
        def f(x, y):
            #exponent = -np.sqrt(sigma*la.norm(x-y)**2)
            exponent = -sigma*la.norm(x-y)**2
            return np.exp(exponent)
        return f

    @staticmethod
    def _polykernel(dimension, offset):
        def f(x, y):
            return (offset + np.dot(x, y)) ** dimension
        return f

    @staticmethod
    def inhomogenous_polynomial(dimension):
        return Kernel._polykernel(dimension=dimension, offset=1.0)

    @staticmethod
    def homogenous_polynomial(dimension):
        return Kernel._polykernel(dimension=dimension, offset=0.0)

    @staticmethod
    def hyperbolic_tangent(kappa, c):
        def f(x, y):
            return np.tanh(kappa * np.dot(x, y) + c)
        return f

def instance(X,T,Y,Y_test, kliep_weights, ulsif_weights,sig = 0.1):
  l = X.shape[0]
  n_t = T.shape[0]
  h = 2.0
  tau = 0.5
  alpha = 0.5 
  
  # Trim T to 500 datapoints
  trim_length = 500
  #inds = [i for i in range(len(T))]
  #test_sample = np.random.choice(inds, trim_length, replace = False)
  T_sub = T
  #lda = LinearDiscriminantAnalysis()
  #lda.fit(X,Y)
  #kpca = KernelPCA(n_components=9, kernel="rbf", fit_inverse_transform=True, gamma=10)
  #kpca.fit(X)
  V_1 = np.identity(l)                      # Unweighted
  #V_2 = Vapnik(X)                           # Vapnik
  V_3= V_matrix_add(T_sub,X,n_t)            # Proposed
  #V_4 = V_matrix_Shimodaira(T_sub,X,n_t,h)  # Shimodaira 
  #V_5 = V_matrix_Sugiyama(T_sub,X,n_t,h,tau)# Sugiyama
  V_6 = V_matrix_Makoto(T_sub,X,n_t,h,alpha)# Makoto
  V_7 = V_matrix_Huang(T_sub,X,n_t,sig)         # Huang
  V_8 = np.diag(kliep_weights)              # KLIEP
  V_9 = np.diag(ulsif_weights)              # ULSIF

  error_1 = test_methods_review(T,X,Y,Y_test,V_1)
  print("Error Unweighted: {}".format(error_1))
  #error_2 = test_methods_review(T,X,Y,Y_test,V_2)
  #print("Error Vapnik: {}".format(error_2))
  error_3 = test_methods_review(T,X,Y,Y_test,V_3)
  print("Error Proposed: {}".format(error_3))
  #error_4 = test_methods_review(T,X,Y,Y_test,V_4)
  #print("Error Shimodaira: {}".format(error_4))
  #error_5 = test_methods_review(T,X,Y,Y_test,V_5)
  #print("Error Sugiyama: {}".format(error_5))
  error_6 = test_methods_review(T,X,Y,Y_test,V_6)
  print("Error Makoto: {}".format(error_6))
  error_7 = test_methods_review(T,X,Y,Y_test,V_7)
  print("Error Huang: {}".format(error_7))
  error_8 = test_methods_review(T,X,Y,Y_test,V_8)
  print("Error KLIEP: {}".format(error_8))
  error_9 = test_methods_review(T,X,Y,Y_test,V_9)
  print("Error ULSIF: {}".format(error_9))
  return [error_1,error_3,error_4,error_5,error_6,error_7, error_8, error_9]
  #return [error_1,error_7]

# %% [markdown]
# Load previously generated datasets:

# %%
dsets_read = open('datasets.p', 'rb')
dataset_info = pickle.load(dsets_read)
matlab = sio.loadmat('matlab_ringnorm.mat')
datasets = [('ringnorm', dataset_info['ringnorm_data'], dataset_info['train_inds_ringnorm'], dataset_info['test_inds_ringnorm'], matlab['kliep_ringnorm'], matlab['ulsif_ringnorm'])]

# %%
for name, data, train_inds, test_inds, kliep, ulsif in datasets:
  errs = [[] for i in range(31)]
  trial = 0
  training_sets = []
  for trial in range(len(train_inds)):
    tr_inds = train_inds[trial]
    te_inds = test_inds[trial]#np.array(list(set(range(len(data))) - set(tr_inds)))
    train = data[tr_inds, :]
    test = data[te_inds, :]
    f = train.shape[1] 
    a = random.sample(range(f-1),5)
    print(a)
    X_train = train[:, a]
    y_train = train[:, -1]
    #print(X_train)
    print("Percentage of y=1: {}".format(sum(y_train)))

    X_test = test[:, a]
    y_test = test[:, -1]
    sigmas = [10+i for i in range(31)]
    for j,sig in enumerate(sigmas):
      print(j)
      errors = instance(X_train, X_test, y_train, y_test, kliep[trial], ulsif[trial],sig)
      if errors[0] > 0:
        errors = errors / errors[0]
        print(errors)
        errs[j].append(errors)
      avg_errors = np.mean(errs[j], axis=0)
      std_errors = np.std(errs[j], axis = 0)
      print("CUMULATIVE\n{}\n{}\n{}".format(name, avg_errors, std_errors))
# Out:
# Streaming output truncated to the last 5000 lines.
# Percentage of y=1: 51.0
# 0
# Error Unweighted: 0.346
# Error Huang: 0.358
# [1.         1.03468208]
# CUMULATIVE
# ringnorm
# [1.         1.18488094]
# [0.         0.35302094]
# 1
# Error Unweighted: 0.346
# Error Huang: 0.364
# [1.         1.05202312]
# CUMULATIVE
# ringnorm
# [1.         1.16087987]
# [0.         0.34417001]
# 2
# Error Unweighted: 0.346
# Error Huang: 0.364
# [1.         1.05202312]
# CUMULATIVE
# ringnorm
# [1.         1.13744917]
# [0.         0.33651542]
# 3
# Error Unweighted: 0.346
# Error Huang: 0.37199999999999994
# [1.         1.07514451]
# CUMULATIVE
# ringnorm
# [1.         1.11350805]
# [0.         0.33211624]
# 4
# Error Unweighted: 0.346
# Error Huang: 0.378
# [1.         1.09248555]
# CUMULATIVE
# ringnorm
# [1.         1.08742856]
# [0.         0.32918977]
# 5
# Error Unweighted: 0.346
# Error Huang: 0.376
# [1.        1.0867052]
# CUMULATIVE
# ringnorm
# [1.         1.06852585]
# [0.         0.32627304]
# 6
# Error Unweighted: 0.346
# Error Huang: 0.378
# [1.         1.09248555]
# CUMULATIVE
# ringnorm
# [1.         1.05521295]
# [0.         0.32622268]
# 7
# Error Unweighted: 0.346
# Error Huang: 0.38
# [1.        1.0982659]
# CUMULATIVE
# ringnorm
# [1.         1.04255796]
# [0.         0.32510138]
# 8
# Error Unweighted: 0.346
# Error Huang: 0.38
# [1.        1.0982659]
# CUMULATIVE
# ringnorm
# [1.         1.03478177]
# [0.         0.32425398]
# 9
# Error Unweighted: 0.346
# Error Huang: 0.378
# [1.         1.09248555]
# CUMULATIVE
# ringnorm
# [1.         1.02722062]
# [0.         0.32053065]
# 10
# Error Unweighted: 0.346
# Error Huang: 0.38
# [1.        1.0982659]
# CUMULATIVE
# ringnorm
# [1.         1.01946038]
# [0.         0.31748792]
# 11
# Error Unweighted: 0.346
# Error Huang: 0.38399999999999995
# [1.         1.10982659]
# CUMULATIVE
# ringnorm
# [1.         1.01100807]
# [0.         0.31564115]
# 12
# Error Unweighted: 0.346
# Error Huang: 0.38599999999999995
# [1.         1.11560694]
# CUMULATIVE
# ringnorm
# [1.         1.00844907]
# [0.         0.31539943]
# 13
# Error Unweighted: 0.346
# Error Huang: 0.38599999999999995
# [1.         1.11560694]
# CUMULATIVE
# ringnorm
# [1.         1.00483485]
# [0.         0.31530903]
# 14
# Error Unweighted: 0.346
# Error Huang: 0.38399999999999995
# [1.         1.10982659]
# CUMULATIVE
# ringnorm
# [1.         0.99947812]
# [0.         0.31237805]
# 15
# Error Unweighted: 0.346
# Error Huang: 0.38599999999999995
# [1.         1.11560694]
# CUMULATIVE
# ringnorm
# [1.        0.9955175]
# [0.         0.30953434]
# 16
# Error Unweighted: 0.346
# Error Huang: 0.38599999999999995
# [1.         1.11560694]
# CUMULATIVE
# ringnorm
# [1.         0.99494688]
# [0.         0.30906827]
# 17
# Error Unweighted: 0.346
# Error Huang: 0.388
# [1.         1.12138728]
# CUMULATIVE
# ringnorm
# [1.         0.99321562]
# [0.         0.30746775]
# 18
# Error Unweighted: 0.346
# Error Huang: 0.39
# [1.         1.12716763]
# CUMULATIVE
# ringnorm
# [1.         0.99344383]
# [0.         0.30707497]
# 19
# Error Unweighted: 0.346
# Error Huang: 0.39399999999999996
# [1.         1.13872832]
# CUMULATIVE
# ringnorm
# [1.         0.99315904]
# [0.         0.30601801]
# 20
# Error Unweighted: 0.346
# Error Huang: 0.39399999999999996
# [1.         1.13872832]
# CUMULATIVE
# ringnorm
# [1.         0.99441388]
# [0.         0.30453611]
# 21
# Error Unweighted: 0.346
# Error Huang: 0.39399999999999996
# [1.         1.13872832]
# CUMULATIVE
# ringnorm
# [1.         0.99415776]
# [0.        0.3032772]
# 22
# Error Unweighted: 0.346
# Error Huang: 0.392
# [1.         1.13294798]
# CUMULATIVE
# ringnorm
# [1.         0.99503871]
# [0.         0.30338006]
# 23
# Error Unweighted: 0.346
# Error Huang: 0.4000000000000001
# [1.         1.15606936]
# CUMULATIVE
# ringnorm
# [1.         0.99697165]
# [0.         0.30415969]
# 24
# Error Unweighted: 0.346
# Error Huang: 0.4000000000000001
# [1.         1.15606936]
# CUMULATIVE
# ringnorm
# [1.         0.99784767]
# [0.         0.30460363]
# 25
# Error Unweighted: 0.346
# Error Huang: 0.402
# [1.         1.16184971]
# CUMULATIVE
# ringnorm
# [1.         1.00194481]
# [0.         0.30572883]
# 26
# Error Unweighted: 0.346
# Error Huang: 0.402
# [1.         1.16184971]
# CUMULATIVE
# ringnorm
# [1.         1.00449694]
# [0.         0.30750683]
# 27
# Error Unweighted: 0.346
# Error Huang: 0.404
# [1.         1.16763006]
# CUMULATIVE
# ringnorm
# [1.         1.00661387]
# [0.        0.3096093]
# 28
# Error Unweighted: 0.346
# Error Huang: 0.404
# [1.         1.16763006]
# CUMULATIVE
# ringnorm
# [1.         1.00956909]
# [0.         0.31119782]
# 29
# Error Unweighted: 0.346
# Error Huang: 0.404
# [1.         1.16763006]
# CUMULATIVE
# ringnorm
# [1.         1.01136452]
# [0.         0.31323398]
# 30
# Error Unweighted: 0.346
# Error Huang: 0.404
# [1.         1.16763006]
# CUMULATIVE
# ringnorm
# [1.         1.01584637]
# [0.         0.31400154]
# [5, 10, 13, 4, 9]
# Percentage of y=1: 53.0
# 0
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.3320000000000001
# [1.         1.08496732]
# CUMULATIVE
# ringnorm
# [1.         1.18366248]
# [0.        0.3510331]
# 1
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.334
# [1.         1.09150327]
# CUMULATIVE
# ringnorm
# [1.         1.16003382]
# [0.         0.34214972]
# 2
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.328
# [1.         1.07189542]
# CUMULATIVE
# ringnorm
# [1.         1.13664974]
# [0.         0.33453458]
# 3
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.32599999999999996
# [1.         1.06535948]
# CUMULATIVE
# ringnorm
# [1.         1.11292087]
# [0.         0.33012723]
# 4
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.32000000000000006
# [1.         1.04575163]
# CUMULATIVE
# ringnorm
# [1.         1.08692031]
# [0.         0.32720833]
# 5
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.318
# [1.         1.03921569]
# CUMULATIVE
# ringnorm
# [1.        1.0681684]
# [0.         0.32429342]
# 6
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.312
# [1.         1.01960784]
# CUMULATIVE
# ringnorm
# [1.         1.05477874]
# [0.         0.32425096]
# 7
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.314
# [1.         1.02614379]
# CUMULATIVE
# ringnorm
# [1.         1.04235778]
# [0.       0.323118]
# 8
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.312
# [1.         1.01960784]
# CUMULATIVE
# ringnorm
# [1.         1.03459672]
# [0.         0.32227506]
# 9
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.312
# [1.         1.01960784]
# CUMULATIVE
# ringnorm
# [1.         1.02712778]
# [0.        0.3185713]
# 10
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.31
# [1.        1.0130719]
# CUMULATIVE
# ringnorm
# [1.         1.01938247]
# [0.         0.31554686]
# 11
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.31
# [1.        1.0130719]
# CUMULATIVE
# ringnorm
# [1.         1.01103324]
# [0.         0.31371069]
# 12
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.308
# [1.         1.00653595]
# CUMULATIVE
# ringnorm
# [1.         1.00842574]
# [0.         0.31347043]
# 13
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.31
# [1.        1.0130719]
# CUMULATIVE
# ringnorm
# [1.        1.0049353]
# [0.         0.31338182]
# 14
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.30599999999999994
# [1. 1.]
# CUMULATIVE
# ringnorm
# [1.         0.99948448]
# [0.         0.31046747]
# 15
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.30399999999999994
# [1.         0.99346405]
# CUMULATIVE
# ringnorm
# [1.         0.99549246]
# [0.         0.30764123]
# 16
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.30599999999999994
# [1. 1.]
# CUMULATIVE
# ringnorm
# [1.        0.9950085]
# [0.         0.30717842]
# 17
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.30599999999999994
# [1. 1.]
# CUMULATIVE
# ringnorm
# [1.         0.99329836]
# [0.        0.3055881]
# 18
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.312
# [1.         1.01960784]
# CUMULATIVE
# ringnorm
# [1.        0.9937629]
# [0.         0.30521033]
# 19
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.316
# [1.         1.03267974]
# CUMULATIVE
# ringnorm
# [1.       0.993641]
# [0.         0.30417725]
# 20
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.32000000000000006
# [1.         1.04575163]
# CUMULATIVE
# ringnorm
# [1.         0.99503995]
# [0.         0.30272593]
# 21
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.314
# [1.         1.02614379]
# CUMULATIVE
# ringnorm
# [1.         0.99454784]
# [0.         0.30144272]
# 22
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.312
# [1.         1.01960784]
# CUMULATIVE
# ringnorm
# [1.         0.99533833]
# [0.         0.30153657]
# 23
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.312
# [1.         1.01960784]
# CUMULATIVE
# ringnorm
# [1.        0.9972477]
# [0.         0.30230958]
# 24
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.31
# [1.        1.0130719]
# CUMULATIVE
# ringnorm
# [1.         0.99803333]
# [0.         0.30274521]
# 25
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.312
# [1.         1.01960784]
# CUMULATIVE
# ringnorm
# [1.         1.00216021]
# [0.         0.30386509]
# 26
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.316
# [1.         1.03267974]
# CUMULATIVE
# ringnorm
# [1.         1.00484063]
# [0.         0.30564169]
# 27
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.316
# [1.         1.03267974]
# CUMULATIVE
# ringnorm
# [1.         1.00693175]
# [0.         0.30772894]
# 28
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.324
# [1.         1.05882353]
# CUMULATIVE
# ringnorm
# [1.         1.01016975]
# [0.         0.30934169]
# 29
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.32599999999999996
# [1.         1.06535948]
# CUMULATIVE
# ringnorm
# [1.         1.01202299]
# [0.         0.31137456]
# 30
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.32599999999999996
# [1.         1.06535948]
# CUMULATIVE
# ringnorm
# [1.         1.01645019]
# [0.         0.31212834]
# [12, 10, 2, 7, 0]
# Percentage of y=1: 48.0
# 0
# Error Unweighted: 0.374
# Error Huang: 0.41
# [1.         1.09625668]
# CUMULATIVE
# ringnorm
# [1.        1.1826094]
# [0.         0.34904233]
# 1
# Error Unweighted: 0.374
# Error Huang: 0.41
# [1.         1.09625668]
# CUMULATIVE
# ringnorm
# [1.         1.15926542]
# [0.        0.3401535]
# 2
# Error Unweighted: 0.374
# Error Huang: 0.40800000000000003
# [1.         1.09090909]
# CUMULATIVE
# ringnorm
# [1.         1.13609865]
# [0.         0.33255065]
# 3
# Error Unweighted: 0.374
# Error Huang: 0.4059999999999999
# [1.        1.0855615]
# CUMULATIVE
# ringnorm
# [1.         1.11259124]
# [0.         0.32814606]
# 4
# Error Unweighted: 0.374
# Error Huang: 0.402
# [1.         1.07486631]
# CUMULATIVE
# ringnorm
# [1.         1.08677508]
# [0.         0.32523388]
# 5
# Error Unweighted: 0.374
# Error Huang: 0.4000000000000001
# [1.         1.06951872]
# CUMULATIVE
# ringnorm
# [1.         1.06818467]
# [0.         0.32233396]
# 6
# Error Unweighted: 0.374
# Error Huang: 0.398
# [1.         1.06417112]
# CUMULATIVE
# ringnorm
# [1.        1.0548919]
# [0.         0.32229335]
# 7
# Error Unweighted: 0.374
# Error Huang: 0.4000000000000001
# [1.         1.06951872]
# CUMULATIVE
# ringnorm
# [1.         1.04268502]
# [0.         0.32117927]
# 8
# Error Unweighted: 0.374
# Error Huang: 0.402
# [1.         1.07486631]
# CUMULATIVE
# ringnorm
# [1.        1.0350819]
# [0.         0.32035789]
# 9
# Error Unweighted: 0.374
# Error Huang: 0.4000000000000001
# [1.         1.06951872]
# CUMULATIVE
# ringnorm
# [1.         1.02763851]
# [0.         0.31668015]
# 10
# Error Unweighted: 0.374
# Error Huang: 0.404
# [1.        1.0802139]
# CUMULATIVE
# ringnorm
# [1.         1.02011538]
# [0.         0.31371042]
# 11
# Error Unweighted: 0.374
# Error Huang: 0.404
# [1.        1.0802139]
# CUMULATIVE
# ringnorm
# [1.         1.01186674]
# [0.         0.31190647]
# 12
# Error Unweighted: 0.374
# Error Huang: 0.404
# [1.        1.0802139]
# CUMULATIVE
# ringnorm
# [1.         1.00929066]
# [0.         0.31167476]
# 13
# Error Unweighted: 0.374
# Error Huang: 0.398
# [1.         1.06417112]
# CUMULATIVE
# ringnorm
# [1.         1.00564899]
# [0.         0.31155529]
# 14
# Error Unweighted: 0.374
# Error Huang: 0.398
# [1.         1.06417112]
# CUMULATIVE
# ringnorm
# [1.         1.00026384]
# [0.        0.3086722]
# 15
# Error Unweighted: 0.374
# Error Huang: 0.4000000000000001
# [1.         1.06951872]
# CUMULATIVE
# ringnorm
# [1.         0.99638434]
# [0.         0.30588899]
# 16
# Error Unweighted: 0.374
# Error Huang: 0.396
# [1.         1.05882353]
# CUMULATIVE
# ringnorm
# [1.         0.99577736]
# [0.         0.30540171]
# 17
# Error Unweighted: 0.374
# Error Huang: 0.398
# [1.         1.06417112]
# CUMULATIVE
# ringnorm
# [1.         0.99415225]
# [0.         0.30384004]
# 18
# Error Unweighted: 0.374
# Error Huang: 0.4000000000000001
# [1.         1.06951872]
# CUMULATIVE
# ringnorm
# [1.         0.99467562]
# [0.         0.30347871]
# 19
# Error Unweighted: 0.374
# Error Huang: 0.4000000000000001
# [1.         1.06951872]
# CUMULATIVE
# ringnorm
# [1.         0.99455519]
# [0.         0.30245262]
# 20
# Error Unweighted: 0.374
# Error Huang: 0.398
# [1.         1.06417112]
# CUMULATIVE
# ringnorm
# [1.         0.99587285]
# [0.         0.30099126]
# 21
# Error Unweighted: 0.374
# Error Huang: 0.4000000000000001
# [1.         1.06951872]
# CUMULATIVE
# ringnorm
# [1.        0.9954511]
# [0.         0.29973292]
# 22
# Error Unweighted: 0.374
# Error Huang: 0.4000000000000001
# [1.         1.06951872]
# CUMULATIVE
# ringnorm
# [1.         0.99623207]
# [0.         0.29982383]
# 23
# Error Unweighted: 0.374
# Error Huang: 0.4000000000000001
# [1.         1.06951872]
# CUMULATIVE
# ringnorm
# [1.         0.99811843]
# [0.         0.30058635]
# 24
# Error Unweighted: 0.374
# Error Huang: 0.4000000000000001
# [1.         1.06951872]
# CUMULATIVE
# ringnorm
# [1.        0.9988946]
# [0.         0.30101697]
# 25
# Error Unweighted: 0.374
# Error Huang: 0.402
# [1.         1.07486631]
# CUMULATIVE
# ringnorm
# [1.         1.00303619]
# [0.         0.30213318]
# 26
# Error Unweighted: 0.374
# Error Huang: 0.402
# [1.         1.07486631]
# CUMULATIVE
# ringnorm
# [1.         1.00568431]
# [0.         0.30389095]
# 27
# Error Unweighted: 0.374
# Error Huang: 0.402
# [1.         1.07486631]
# CUMULATIVE
# ringnorm
# [1.         1.00775024]
# [0.         0.30595932]
# 28
# Error Unweighted: 0.374
# Error Huang: 0.404
# [1.        1.0802139]
# CUMULATIVE
# ringnorm
# [1.         1.01101366]
# [0.         0.30756749]
# 29
# Error Unweighted: 0.374
# Error Huang: 0.404
# [1.        1.0802139]
# CUMULATIVE
# ringnorm
# [1.         1.01284457]
# [0.         0.30958253]
# 30
# Error Unweighted: 0.374
# Error Huang: 0.404
# [1.        1.0802139]
# CUMULATIVE
# ringnorm
# [1.         1.01721843]
# [0.         0.31032034]
# [8, 13, 2, 9, 16]
# Percentage of y=1: 47.0
# 0
# Error Unweighted: 0.358
# Error Huang: 0.5219999999999999
# [1.         1.45810056]
# CUMULATIVE
# ringnorm
# [1.         1.18588906]
# [0.         0.34824265]
# 1
# Error Unweighted: 0.358
# Error Huang: 0.518
# [1.         1.44692737]
# CUMULATIVE
# ringnorm
# [1.         1.16268997]
# [0.         0.33955906]
# 2
# Error Unweighted: 0.358
# Error Huang: 0.49200000000000005
# [1.         1.37430168]
# CUMULATIVE
# ringnorm
# [1.        1.1389344]
# [0.         0.33157327]
# 3
# Error Unweighted: 0.358
# Error Huang: 0.4680000000000001
# [1.         1.30726257]
# CUMULATIVE
# ringnorm
# [1.         1.11490876]
# [0.         0.32686958]
# 4
# Error Unweighted: 0.358
# Error Huang: 0.43
# [1.         1.20111732]
# CUMULATIVE
# ringnorm
# [1.         1.08813629]
# [0.         0.32352993]
# 5
# Error Unweighted: 0.358
# Error Huang: 0.4059999999999999
# [1.         1.13407821]
# CUMULATIVE
# ringnorm
# [1.         1.06896912]
# [0.         0.32048926]
# 6
# Error Unweighted: 0.358
# Error Huang: 0.39
# [1.         1.08938547]
# CUMULATIVE
# ringnorm
# [1.         1.05530254]
# [0.         0.32039104]
# 7
# Error Unweighted: 0.358
# Error Huang: 0.362
# [1.         1.01117318]
# CUMULATIVE
# ringnorm
# [1.         1.04230988]
# [0.         0.31928006]
# 8
# Error Unweighted: 0.358
# Error Huang: 0.348
# [1.         0.97206704]
# CUMULATIVE
# ringnorm
# [1.         1.03433172]
# [0.         0.31851862]
# 9
# Error Unweighted: 0.358
# Error Huang: 0.3400000000000001
# [1.         0.94972067]
# CUMULATIVE
# ringnorm
# [1.         1.02671092]
# [0.         0.31490292]
# 10
# Error Unweighted: 0.358
# Error Huang: 0.32000000000000006
# [1.         0.89385475]
# CUMULATIVE
# ringnorm
# [1.         1.01861227]
# [0.         0.31213804]
# 11
# Error Unweighted: 0.358
# Error Huang: 0.314
# [1.         0.87709497]
# CUMULATIVE
# ringnorm
# [1.         1.01026232]
# [0.        0.3103887]
# 12
# Error Unweighted: 0.358
# Error Huang: 0.316
# [1.         0.88268156]
# CUMULATIVE
# ringnorm
# [1.         1.00778341]
# [0.         0.31011816]
# 13
# Error Unweighted: 0.358
# Error Huang: 0.314
# [1.         0.87709497]
# CUMULATIVE
# ringnorm
# [1.         1.00411858]
# [0.         0.31000894]
# 14
# Error Unweighted: 0.358
# Error Huang: 0.31
# [1.         0.86592179]
# CUMULATIVE
# ringnorm
# [1.         0.99866453]
# [0.         0.30717512]
# 15
# Error Unweighted: 0.358
# Error Huang: 0.308
# [1.        0.8603352]
# CUMULATIVE
# ringnorm
# [1.         0.99476471]
# [0.         0.30442059]
# 16
# Error Unweighted: 0.358
# Error Huang: 0.316
# [1.         0.88268156]
# CUMULATIVE
# ringnorm
# [1.         0.99443098]
# [0.         0.30382611]
# 17
# Error Unweighted: 0.358
# Error Huang: 0.314
# [1.         0.87709497]
# CUMULATIVE
# ringnorm
# [1.         0.99275871]
# [0.         0.30229277]
# 18
# Error Unweighted: 0.358
# Error Huang: 0.312
# [1.         0.87150838]
# CUMULATIVE
# ringnorm
# [1.         0.99320935]
# [0.        0.3019625]
# 19
# Error Unweighted: 0.358
# Error Huang: 0.314
# [1.         0.87709497]
# CUMULATIVE
# ringnorm
# [1.         0.99315685]
# [0.        0.3009167]
# 20
# Error Unweighted: 0.358
# Error Huang: 0.318
# [1.         0.88826816]
# CUMULATIVE
# ringnorm
# [1.         0.99459184]
# [0.         0.29942181]
# 21
# Error Unweighted: 0.358
# Error Huang: 0.32000000000000006
# [1.         0.89385475]
# CUMULATIVE
# ringnorm
# [1.         0.99424162]
# [0.         0.29814714]
# 22
# Error Unweighted: 0.358
# Error Huang: 0.324
# [1.         0.90502793]
# CUMULATIVE
# ringnorm
# [1.         0.99514631]
# [0.         0.29819793]
# 23
# Error Unweighted: 0.358
# Error Huang: 0.328
# [1.         0.91620112]
# CUMULATIVE
# ringnorm
# [1.         0.99714323]
# [0.         0.29892385]
# 24
# Error Unweighted: 0.358
# Error Huang: 0.338
# [1.         0.94413408]
# CUMULATIVE
# ringnorm
# [1.         0.99824269]
# [0.         0.29927877]
# 25
# Error Unweighted: 0.358
# Error Huang: 0.342
# [1.         0.95530726]
# CUMULATIVE
# ringnorm
# [1.         1.00246799]
# [0.         0.30037399]
# 26
# Error Unweighted: 0.358
# Error Huang: 0.3439999999999999
# [1.         0.96089385]
# CUMULATIVE
# ringnorm
# [1.         1.00515109]
# [0.         0.30211571]
# 27
# Error Unweighted: 0.358
# Error Huang: 0.346
# [1.         0.96648045]
# CUMULATIVE
# ringnorm
# [1.         1.00725893]
# [0.         0.30416562]
# 28
# Error Unweighted: 0.358
# Error Huang: 0.346
# [1.         0.96648045]
# CUMULATIVE
# ringnorm
# [1.        1.0104835]
# [0.        0.3057694]
# 29
# Error Unweighted: 0.358
# Error Huang: 0.3439999999999999
# [1.         0.96089385]
# CUMULATIVE
# ringnorm
# [1.         1.01222611]
# [0.         0.30778584]
# 30
# Error Unweighted: 0.358
# Error Huang: 0.3439999999999999
# [1.         0.96089385]
# CUMULATIVE
# ringnorm
# [1.        1.0165479]
# [0.         0.30852814]
# [17, 7, 14, 13, 15]
# Percentage of y=1: 59.0
# 0
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.37000000000000005
# [1.         1.20915033]
# CUMULATIVE
# ringnorm
# [1.         1.18616272]
# [0.         0.34619719]
# 1
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.3400000000000001
# [1.         1.11111111]
# CUMULATIVE
# ringnorm
# [1.         1.16208316]
# [0.         0.33760156]
# 2
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.322
# [1.         1.05228758]
# CUMULATIVE
# ringnorm
# [1.         1.13791502]
# [0.         0.32974944]
# 3
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.314
# [1.         1.02614379]
# CUMULATIVE
# ringnorm
# [1.         1.11386447]
# [0.         0.32508205]
# 4
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.302
# [1.        0.9869281]
# CUMULATIVE
# ringnorm
# [1.         1.08694561]
# [0.         0.32180627]
# 5
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.308
# [1.         1.00653595]
# CUMULATIVE
# ringnorm
# [1.         1.06823461]
# [0.         0.31866956]
# 6
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.31
# [1.        1.0130719]
# CUMULATIVE
# ringnorm
# [1.         1.05480571]
# [0.         0.31853336]
# 7
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.316
# [1.         1.03267974]
# CUMULATIVE
# ringnorm
# [1.         1.04219659]
# [0.         0.31739809]
# 8
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.334
# [1.         1.09150327]
# CUMULATIVE
# ringnorm
# [1.         1.03500433]
# [0.         0.31669944]
# 9
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.336
# [1.         1.09803922]
# CUMULATIVE
# ringnorm
# [1.         1.02755007]
# [0.         0.31313953]
# 10
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.358
# [1.         1.16993464]
# CUMULATIVE
# ringnorm
# [1.         1.02039254]
# [0.         0.31072519]
# 11
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.37199999999999994
# [1.         1.21568627]
# CUMULATIVE
# ringnorm
# [1.         1.01267907]
# [0.         0.30935148]
# 12
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.382
# [1.         1.24836601]
# CUMULATIVE
# ringnorm
# [1.         1.01061379]
# [0.         0.30937801]
# 13
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.382
# [1.         1.24836601]
# CUMULATIVE
# ringnorm
# [1.         1.00699208]
# [0.         0.30930321]
# 14
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.382
# [1.         1.24836601]
# CUMULATIVE
# ringnorm
# [1.         1.00160219]
# [0.         0.30654753]
# 15
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.388
# [1.         1.26797386]
# CUMULATIVE
# ringnorm
# [1.         0.99797894]
# [0.         0.30405503]
# 16
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.39399999999999996
# [1.        1.2875817]
# CUMULATIVE
# ringnorm
# [1.         0.99787981]
# [0.         0.30368311]
# 17
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.392
# [1.         1.28104575]
# CUMULATIVE
# ringnorm
# [1.         0.99615032]
# [0.         0.30211273]
# 18
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.392
# [1.         1.28104575]
# CUMULATIVE
# ringnorm
# [1.         0.99659566]
# [0.         0.30178116]
# 19
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.396
# [1.         1.29411765]
# CUMULATIVE
# ringnorm
# [1.         0.99669757]
# [0.         0.30089639]
# 20
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.398
# [1.         1.30065359]
# CUMULATIVE
# ringnorm
# [1.         0.99819257]
# [0.         0.29947914]
# 21
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.398
# [1.         1.30065359]
# CUMULATIVE
# ringnorm
# [1.         0.99784647]
# [0.         0.29822392]
# 22
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.4000000000000001
# [1.         1.30718954]
# CUMULATIVE
# ringnorm
# [1.        0.9988174]
# [0.         0.29834196]
# 23
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.402
# [1.         1.31372549]
# CUMULATIVE
# ringnorm
# [1.         1.00086772]
# [0.         0.29911447]
# 24
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.404
# [1.         1.32026144]
# CUMULATIVE
# ringnorm
# [1.         1.00203114]
# [0.         0.29953238]
# 25
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.4059999999999999
# [1.         1.32679739]
# CUMULATIVE
# ringnorm
# [1.         1.00628363]
# [0.         0.30064271]
# 26
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.41
# [1.         1.33986928]
# CUMULATIVE
# ringnorm
# [1.         1.00908895]
# [0.         0.30249407]
# 27
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.41
# [1.         1.33986928]
# CUMULATIVE
# ringnorm
# [1.         1.01117199]
# [0.         0.30449057]
# 28
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.41
# [1.         1.33986928]
# CUMULATIVE
# ringnorm
# [1.         1.01435863]
# [0.        0.3060333]
# 29
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.414
# [1.         1.35294118]
# CUMULATIVE
# ringnorm
# [1.         1.01623452]
# [0.         0.30816763]
# 30
# Error Unweighted: 0.30599999999999994
# Error Huang: 0.414
# [1.         1.35294118]
# CUMULATIVE
# ringnorm
# [1.         1.02050546]
# [0.         0.30884523]
# [15, 1, 2, 16, 7]
# Percentage of y=1: 45.0
# 0
# Error Unweighted: 0.46
# Error Huang: 0.37000000000000005
# [1.         0.80434783]
# CUMULATIVE
# ringnorm
# [1.         1.18172301]
# [0.         0.34660395]
# 1
# Error Unweighted: 0.46
# Error Huang: 0.3439999999999999
# [1.         0.74782609]
# CUMULATIVE
# ringnorm
# [1.         1.15726621]
# [0.         0.33855838]
# 2
# Error Unweighted: 0.46
# Error Huang: 0.3400000000000001
# [1.         0.73913043]
# CUMULATIVE
# ringnorm
# [1.         1.13327799]
# [0.        0.3306025]
# 3
# Error Unweighted: 0.46
# Error Huang: 0.342
# [1.         0.74347826]
# CUMULATIVE
# ringnorm
# [1.         1.10955765]
# [0.         0.32561658]
# 4
# Error Unweighted: 0.46
# Error Huang: 0.3320000000000001
# [1.         0.72173913]
# CUMULATIVE
# ringnorm
# [1.         1.08269902]
# [0.         0.32231653]
# 5
# Error Unweighted: 0.46
# Error Huang: 0.338
# [1.         0.73478261]
# CUMULATIVE
# ringnorm
# [1.         1.06435726]
# [0.         0.31882181]
# 6
# Error Unweighted: 0.46
# Error Huang: 0.338
# [1.         0.73478261]
# CUMULATIVE
# ringnorm
# [1.         1.05108451]
# [0.         0.31852898]
# 7
# Error Unweighted: 0.46
# Error Huang: 0.342
# [1.         0.74347826]
# CUMULATIVE
# ringnorm
# [1.         1.03872312]
# [0.         0.31716818]
# 8
# Error Unweighted: 0.46
# Error Huang: 0.352
# [1.         0.76521739]
# CUMULATIVE
# ringnorm
# [1.         1.03186727]
# [0.         0.31617838]
# 9
# Error Unweighted: 0.46
# Error Huang: 0.352
# [1.         0.76521739]
# CUMULATIVE
# ringnorm
# [1.         1.02449969]
# [0.         0.31258133]
# 10
# Error Unweighted: 0.46
# Error Huang: 0.356
# [1.         0.77391304]
# CUMULATIVE
# ringnorm
# [1.        1.0175265]
# [0.        0.3100414]
# 11
# Error Unweighted: 0.46
# Error Huang: 0.356
# [1.         0.77391304]
# CUMULATIVE
# ringnorm
# [1.         1.00990272]
# [0.         0.30861101]
# 12
# Error Unweighted: 0.46
# Error Huang: 0.358
# [1.         0.77826087]
# CUMULATIVE
# ringnorm
# [1.         1.00791201]
# [0.         0.30858103]
# 13
# Error Unweighted: 0.46
# Error Huang: 0.364
# [1.         0.79130435]
# CUMULATIVE
# ringnorm
# [1.         1.00448408]
# [0.         0.30836781]
# 14
# Error Unweighted: 0.46
# Error Huang: 0.364
# [1.         0.79130435]
# CUMULATIVE
# ringnorm
# [1.         0.99915687]
# [0.         0.30559281]
# 15
# Error Unweighted: 0.46
# Error Huang: 0.368
# [1.  0.8]
# CUMULATIVE
# ringnorm
# [1.         0.99567685]
# [0.         0.30302629]
# 16
# Error Unweighted: 0.46
# Error Huang: 0.368
# [1.  0.8]
# CUMULATIVE
# ringnorm
# [1.         0.99557888]
# [0.        0.3026567]
# 17
# Error Unweighted: 0.46
# Error Huang: 0.368
# [1.  0.8]
# CUMULATIVE
# ringnorm
# [1.        0.9938695]
# [0.         0.30108633]
# 18
# Error Unweighted: 0.46
# Error Huang: 0.374
# [1.         0.81304348]
# CUMULATIVE
# ringnorm
# [1.         0.99446133]
# [0.         0.30066609]
# 19
# Error Unweighted: 0.46
# Error Huang: 0.374
# [1.         0.81304348]
# CUMULATIVE
# ringnorm
# [1.         0.99456206]
# [0.         0.29978909]
# 20
# Error Unweighted: 0.46
# Error Huang: 0.376
# [1.        0.8173913]
# CUMULATIVE
# ringnorm
# [1.         0.99609023]
# [0.         0.29836314]
# 21
# Error Unweighted: 0.46
# Error Huang: 0.376
# [1.        0.8173913]
# CUMULATIVE
# ringnorm
# [1.         0.99574815]
# [0.         0.29711546]
# 22
# Error Unweighted: 0.46
# Error Huang: 0.376
# [1.        0.8173913]
# CUMULATIVE
# ringnorm
# [1.        0.9967078]
# [0.         0.29723936]
# 23
# Error Unweighted: 0.46
# Error Huang: 0.378
# [1.         0.82173913]
# CUMULATIVE
# ringnorm
# [1.         0.99878483]
# [0.         0.29798975]
# 24
# Error Unweighted: 0.46
# Error Huang: 0.378
# [1.         0.82173913]
# CUMULATIVE
# ringnorm
# [1.         0.99993473]
# [0.         0.29841241]
# 25
# Error Unweighted: 0.46
# Error Huang: 0.38399999999999995
# [1.         0.83478261]
# CUMULATIVE
# ringnorm
# [1.         1.00428943]
# [0.         0.29945461]
# 26
# Error Unweighted: 0.46
# Error Huang: 0.388
# [1.         0.84347826]
# CUMULATIVE
# ringnorm
# [1.         1.00716325]
# [0.         0.30125386]
# 27
# Error Unweighted: 0.46
# Error Huang: 0.39
# [1.         0.84782609]
# CUMULATIVE
# ringnorm
# [1.         1.00927262]
# [0.         0.30322117]
# 28
# Error Unweighted: 0.46
# Error Huang: 0.392
# [1.         0.85217391]
# CUMULATIVE
# ringnorm
# [1.         1.01247276]
# [0.         0.30474523]
# 29
# Error Unweighted: 0.46
# Error Huang: 0.396
# [1.         0.86086957]
# CUMULATIVE
# ringnorm
# [1.         1.01442795]
# [0.         0.30682313]
# 30
# Error Unweighted: 0.46
# Error Huang: 0.396
# [1.         0.86086957]
# CUMULATIVE
# ringnorm
# [1.         1.01864923]
# [0.         0.30752092]
# [11, 10, 12, 1, 3]
# Percentage of y=1: 50.0
# 0
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.4059999999999999
# [1.         1.12777778]
# CUMULATIVE
# ringnorm
# [1.         1.18110295]
# [0.         0.34465418]
# 1
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.38599999999999995
# [1.         1.07222222]
# CUMULATIVE
# ringnorm
# [1.        1.1562887]
# [0.         0.33672906]
# 2
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.37000000000000005
# [1.         1.02777778]
# CUMULATIVE
# ringnorm
# [1.         1.13206535]
# [0.         0.32888931]
# 3
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.3439999999999999
# [1.         0.95555556]
# CUMULATIVE
# ringnorm
# [1.         1.10778751]
# [0.         0.32415573]
# 4
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.32599999999999996
# [1.         0.90555556]
# CUMULATIVE
# ringnorm
# [1.         1.08066289]
# [0.        0.3210146]
# 5
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.318
# [1.         0.88333333]
# CUMULATIVE
# ringnorm
# [1.         1.06227653]
# [0.         0.31757097]
# 6
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.32000000000000006
# [1.         0.88888889]
# CUMULATIVE
# ringnorm
# [1.         1.04922019]
# [0.         0.31716464]
# 7
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.32599999999999996
# [1.         0.90555556]
# CUMULATIVE
# ringnorm
# [1.         1.03719246]
# [0.         0.31565943]
# 8
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.32000000000000006
# [1.         0.88888889]
# CUMULATIVE
# ringnorm
# [1.         1.03022384]
# [0.         0.31472524]
# 9
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.318
# [1.         0.88333333]
# CUMULATIVE
# ringnorm
# [1.         1.02287709]
# [0.         0.31114376]
# 10
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.32000000000000006
# [1.         0.88888889]
# CUMULATIVE
# ringnorm
# [1.        1.0160479]
# [0.         0.30855923]
# 11
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.324
# [1.  0.9]
# CUMULATIVE
# ringnorm
# [1.         1.00863947]
# [0.         0.30705581]
# 12
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.3400000000000001
# [1.         0.94444444]
# CUMULATIVE
# ringnorm
# [1.        1.0071825]
# [0.         0.30687703]
# 13
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.342
# [1.   0.95]
# CUMULATIVE
# ringnorm
# [1.         1.00385783]
# [0.         0.30664546]
# 14
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.338
# [1.         0.93888889]
# CUMULATIVE
# ringnorm
# [1.         0.99846414]
# [0.         0.30389936]
# 15
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.342
# [1.   0.95]
# CUMULATIVE
# ringnorm
# [1.         0.99515183]
# [0.         0.30131906]
# 16
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.348
# [1.         0.96666667]
# CUMULATIVE
# ringnorm
# [1.         0.99524656]
# [0.         0.30092805]
# 17
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.352
# [1.         0.97777778]
# CUMULATIVE
# ringnorm
# [1.         0.99368454]
# [0.         0.29935587]
# 18
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.366
# [1.         1.01666667]
# CUMULATIVE
# ringnorm
# [1.         0.99471656]
# [0.        0.2989425]
# 19
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.37000000000000005
# [1.         1.02777778]
# CUMULATIVE
# ringnorm
# [1.         0.99494385]
# [0.         0.29808221]
# 20
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.374
# [1.         1.03888889]
# CUMULATIVE
# ringnorm
# [1.         0.99658217]
# [0.         0.29667853]
# 21
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.376
# [1.         1.04444444]
# CUMULATIVE
# ringnorm
# [1.         0.99630788]
# [0.         0.29544857]
# 22
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.38399999999999995
# [1.         1.06666667]
# CUMULATIVE
# ringnorm
# [1.         0.99751192]
# [0.         0.29562022]
# 23
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.38599999999999995
# [1.         1.07222222]
# CUMULATIVE
# ringnorm
# [1.         0.99962894]
# [0.         0.29637561]
# 24
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.388
# [1.         1.07777778]
# CUMULATIVE
# ringnorm
# [1.         1.00082947]
# [0.         0.29680845]
# 25
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.398
# [1.         1.10555556]
# CUMULATIVE
# ringnorm
# [1.         1.00545341]
# [0.         0.29792425]
# 26
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.4000000000000001
# [1.         1.11111111]
# CUMULATIVE
# ringnorm
# [1.         1.00835805]
# [0.         0.29972238]
# 27
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.404
# [1.         1.12222222]
# CUMULATIVE
# ringnorm
# [1.         1.01057089]
# [0.         0.30171379]
# 28
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.40800000000000003
# [1.         1.13333333]
# CUMULATIVE
# ringnorm
# [1.         1.01386196]
# [0.         0.30326252]
# 29
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.40800000000000003
# [1.         1.13333333]
# CUMULATIVE
# ringnorm
# [1.         1.01579468]
# [0.         0.30531787]
# 30
# Error Unweighted: 0.36000000000000004
# Error Huang: 0.412
# [1.         1.14444444]
# CUMULATIVE
# ringnorm
# [1.         1.02009515]
# [0.         0.30604234]
# [13, 0, 11, 14, 5]
# Percentage of y=1: 48.0
# 0
# Error Unweighted: 0.338
# Error Huang: 0.322
# [1.         0.95266272]
# CUMULATIVE
# ringnorm
# [1.         1.17850704]
# [0.         0.34354466]
# 1
# Error Unweighted: 0.338
# Error Huang: 0.312
# [1.         0.92307692]
# CUMULATIVE
# ringnorm
# [1.         1.15363856]
# [0.        0.3357216]
# 2
# Error Unweighted: 0.338
# Error Huang: 0.312
# [1.         0.92307692]
# CUMULATIVE
# ringnorm
# [1.         1.12969048]
# [0.         0.32776466]
# 3
# Error Unweighted: 0.338
# Error Huang: 0.314
# [1.         0.92899408]
# CUMULATIVE
# ringnorm
# [1.         1.10575577]
# [0.         0.32286533]
# 4
# Error Unweighted: 0.338
# Error Huang: 0.30599999999999994
# [1.         0.90532544]
# CUMULATIVE
# ringnorm
# [1.         1.07867042]
# [0.         0.31972603]
# 5
# Error Unweighted: 0.338
# Error Huang: 0.30599999999999994
# [1.         0.90532544]
# CUMULATIVE
# ringnorm
# [1.         1.06049299]
# [0.         0.31619935]
# 6
# Error Unweighted: 0.338
# Error Huang: 0.308
# [1.        0.9112426]
# CUMULATIVE
# ringnorm
# [1.         1.04765227]
# [0.         0.31569634]
# 7
# Error Unweighted: 0.338
# Error Huang: 0.308
# [1.        0.9112426]
# CUMULATIVE
# ringnorm
# [1.         1.03576121]
# [0.         0.31414457]
# 8
# Error Unweighted: 0.338
# Error Huang: 0.30399999999999994
# [1.         0.89940828]
# CUMULATIVE
# ringnorm
# [1.        1.0287373]
# [0.         0.31323895]
# 9
# Error Unweighted: 0.338
# Error Huang: 0.30399999999999994
# [1.         0.89940828]
# CUMULATIVE
# ringnorm
# [1.         1.02147404]
# [0.         0.30964752]
# 10
# Error Unweighted: 0.338
# Error Huang: 0.308
# [1.        0.9112426]
# CUMULATIVE
# ringnorm
# [1.         1.01485693]
# [0.         0.30700208]
# 11
# Error Unweighted: 0.338
# Error Huang: 0.30599999999999994
# [1.         0.90532544]
# CUMULATIVE
# ringnorm
# [1.         1.00746545]
# [0.         0.30550251]
# 12
# Error Unweighted: 0.338
# Error Huang: 0.31
# [1.         0.91715976]
# CUMULATIVE
# ringnorm
# [1.         1.00615951]
# [0.         0.30527759]
# 13
# Error Unweighted: 0.338
# Error Huang: 0.314
# [1.         0.92899408]
# CUMULATIVE
# ringnorm
# [1.         1.00300711]
# [0.         0.30500142]
# 14
# Error Unweighted: 0.338
# Error Huang: 0.316
# [1.         0.93491124]
# CUMULATIVE
# ringnorm
# [1.         0.99774194]
# [0.        0.3022428]
# 15
# Error Unweighted: 0.338
# Error Huang: 0.312
# [1.         0.92307692]
# CUMULATIVE
# ringnorm
# [1.        0.9943328]
# [0.         0.29969951]
# 16
# Error Unweighted: 0.338
# Error Huang: 0.312
# [1.         0.92307692]
# CUMULATIVE
# ringnorm
# [1.         0.99442645]
# [0.         0.29931111]
# 17
# Error Unweighted: 0.338
# Error Huang: 0.31
# [1.         0.91715976]
# CUMULATIVE
# ringnorm
# [1.         0.99281494]
# [0.         0.29776061]
# 18
# Error Unweighted: 0.338
# Error Huang: 0.30399999999999994
# [1.         0.89940828]
# CUMULATIVE
# ringnorm
# [1.         0.99363352]
# [0.         0.29741073]
# 19
# Error Unweighted: 0.338
# Error Huang: 0.30399999999999994
# [1.         0.89940828]
# CUMULATIVE
# ringnorm
# [1.         0.99385822]
# [0.         0.29655666]
# 20
# Error Unweighted: 0.338
# Error Huang: 0.30599999999999994
# [1.         0.90532544]
# CUMULATIVE
# ringnorm
# [1.         0.99554516]
# [0.         0.29514657]
# 21
# Error Unweighted: 0.338
# Error Huang: 0.308
# [1.        0.9112426]
# CUMULATIVE
# ringnorm
# [1.         0.99534123]
# [0.         0.29390342]
# 22
# Error Unweighted: 0.338
# Error Huang: 0.316
# [1.         0.93491124]
# CUMULATIVE
# ringnorm
# [1.         0.99680055]
# [0.         0.29401064]
# 23
# Error Unweighted: 0.338
# Error Huang: 0.314
# [1.         0.92899408]
# CUMULATIVE
# ringnorm
# [1.         0.99882627]
# [0.         0.29478193]
# 24
# Error Unweighted: 0.338
# Error Huang: 0.316
# [1.         0.93491124]
# CUMULATIVE
# ringnorm
# [1.        1.0000804]
# [0.         0.29519991]
# 25
# Error Unweighted: 0.338
# Error Huang: 0.316
# [1.         0.93491124]
# CUMULATIVE
# ringnorm
# [1.         1.00465179]
# [0.         0.29632101]
# 26
# Error Unweighted: 0.338
# Error Huang: 0.316
# [1.         0.93491124]
# CUMULATIVE
# ringnorm
# [1.         1.00752343]
# [0.         0.29811621]
# 27
# Error Unweighted: 0.338
# Error Huang: 0.318
# [1.        0.9408284]
# CUMULATIVE
# ringnorm
# [1.         1.00977836]
# [0.         0.30008567]
# 28
# Error Unweighted: 0.338
# Error Huang: 0.318
# [1.        0.9408284]
# CUMULATIVE
# ringnorm
# [1.         1.01303203]
# [0.         0.30163387]
# 29
# Error Unweighted: 0.338
# Error Huang: 0.316
# [1.         0.93491124]
# CUMULATIVE
# ringnorm
# [1.         1.01487555]
# [0.         0.30369918]
# 30
# Error Unweighted: 0.338
# Error Huang: 0.318
# [1.        0.9408284]
# CUMULATIVE
# ringnorm
# [1.        1.0191944]
# [0.         0.30441446]
# [2, 11, 12, 13, 0]
# Percentage of y=1: 53.0
# 0
# Error Unweighted: 0.31
# Error Huang: 0.46599999999999997
# [1.         1.50322581]
# CUMULATIVE
# ringnorm
# [1.         1.18215556]
# [0.         0.34331948]
# 1
# Error Unweighted: 0.31
# Error Huang: 0.438
# [1.         1.41290323]
# CUMULATIVE
# ringnorm
# [1.         1.15655165]
# [0.         0.33494683]
# 2
# Error Unweighted: 0.31
# Error Huang: 0.4159999999999999
# [1.         1.34193548]
# CUMULATIVE
# ringnorm
# [1.         1.13207525]
# [0.         0.32668497]
# 3
# Error Unweighted: 0.31
# Error Huang: 0.412
# [1.         1.32903226]
# CUMULATIVE
# ringnorm
# [1.         1.10826449]
# [0.         0.32190776]
# 4
# Error Unweighted: 0.31
# Error Huang: 0.404
# [1.         1.30322581]
# CUMULATIVE
# ringnorm
# [1.         1.08119351]
# [0.         0.31880456]
# 5
# Error Unweighted: 0.31
# Error Huang: 0.38599999999999995
# [1.         1.24516129]
# CUMULATIVE
# ringnorm
# [1.         1.06256792]
# [0.         0.31501985]
# 6
# Error Unweighted: 0.31
# Error Huang: 0.38
# [1.         1.22580645]
# CUMULATIVE
# ringnorm
# [1.       1.049654]
# [0.         0.31447888]
# 7
# Error Unweighted: 0.31
# Error Huang: 0.364
# [1.         1.17419355]
# CUMULATIVE
# ringnorm
# [1.         1.03731663]
# [0.         0.31271532]
# 8
# Error Unweighted: 0.31
# Error Huang: 0.348
# [1.         1.12258065]
# CUMULATIVE
# ringnorm
# [1.         1.02979172]
# [0.         0.31163123]
# 9
# Error Unweighted: 0.31
# Error Huang: 0.3320000000000001
# [1.         1.07096774]
# CUMULATIVE
# ringnorm
# [1.         1.02203015]
# [0.        0.3079472]
# 10
# Error Unweighted: 0.31
# Error Huang: 0.324
# [1.         1.04516129]
# CUMULATIVE
# ringnorm
# [1.         1.01519743]
# [0.         0.30528919]
# 11
# Error Unweighted: 0.31
# Error Huang: 0.322
# [1.         1.03870968]
# CUMULATIVE
# ringnorm
# [1.        1.0078165]
# [0.         0.30379921]
# 12
# Error Unweighted: 0.31
# Error Huang: 0.314
# [1.         1.01290323]
# CUMULATIVE
# ringnorm
# [1.         1.00623529]
# [0.         0.30355853]
# 13
# Error Unweighted: 0.31
# Error Huang: 0.314
# [1.         1.01290323]
# CUMULATIVE
# ringnorm
# [1.        1.0031183]
# [0.         0.30328488]
# 14
# Error Unweighted: 0.31
# Error Huang: 0.314
# [1.         1.01290323]
# CUMULATIVE
# ringnorm
# [1.         0.99791229]
# [0.         0.30054426]
# 15
# Error Unweighted: 0.31
# Error Huang: 0.318
# [1.         1.02580645]
# CUMULATIVE
# ringnorm
# [1.         0.99468644]
# [0.         0.29802952]
# 16
# Error Unweighted: 0.31
# Error Huang: 0.318
# [1.         1.02580645]
# CUMULATIVE
# ringnorm
# [1.         0.99477904]
# [0.         0.29764322]
# 17
# Error Unweighted: 0.31
# Error Huang: 0.32000000000000006
# [1.         1.03225806]
# CUMULATIVE
# ringnorm
# [1.         0.99325812]
# [0.         0.29611226]
# 18
# Error Unweighted: 0.31
# Error Huang: 0.322
# [1.         1.03870968]
# CUMULATIVE
# ringnorm
# [1.         0.99413999]
# [0.         0.29577332]
# 19
# Error Unweighted: 0.31
# Error Huang: 0.322
# [1.         1.03870968]
# CUMULATIVE
# ringnorm
# [1.         0.99436216]
# [0.         0.29492379]
# 20
# Error Unweighted: 0.31
# Error Huang: 0.324
# [1.         1.04516129]
# CUMULATIVE
# ringnorm
# [1.         0.99610264]
# [0.         0.29353035]
# 21
# Error Unweighted: 0.31
# Error Huang: 0.328
# [1.         1.05806452]
# CUMULATIVE
# ringnorm
# [1.         0.99604598]
# [0.         0.29232238]
# 22
# Error Unweighted: 0.31
# Error Huang: 0.336
# [1.         1.08387097]
# CUMULATIVE
# ringnorm
# [1.         0.99777887]
# [0.         0.29249824]
# 23
# Error Unweighted: 0.31
# Error Huang: 0.3400000000000001
# [1.         1.09677419]
# CUMULATIVE
# ringnorm
# [1.         0.99992681]
# [0.         0.29330293]
# 24
# Error Unweighted: 0.31
# Error Huang: 0.3439999999999999
# [1.         1.10967742]
# CUMULATIVE
# ringnorm
# [1.         1.00131183]
# [0.         0.29376402]
# 25
# Error Unweighted: 0.31
# Error Huang: 0.348
# [1.         1.12258065]
# CUMULATIVE
# ringnorm
# [1.         1.00597684]
# [0.         0.29491365]
# 26
# Error Unweighted: 0.31
# Error Huang: 0.35
# [1.         1.12903226]
# CUMULATIVE
# ringnorm
# [1.        1.0088887]
# [0.         0.29671321]
# 27
# Error Unweighted: 0.31
# Error Huang: 0.352
# [1.         1.13548387]
# CUMULATIVE
# ringnorm
# [1.         1.01119079]
# [0.         0.29868906]
# 28
# Error Unweighted: 0.31
# Error Huang: 0.356
# [1.        1.1483871]
# CUMULATIVE
# ringnorm
# [1.         1.01455288]
# [0.         0.30027362]
# 29
# Error Unweighted: 0.31
# Error Huang: 0.36000000000000004
# [1.         1.16129032]
# CUMULATIVE
# ringnorm
# [1.         1.01652066]
# [0.         0.30238225]
# 30
# Error Unweighted: 0.31
# Error Huang: 0.366
# [1.         1.18064516]
# CUMULATIVE
# ringnorm
# [1.         1.02100845]
# [0.        0.3031774]
# [3, 1, 13, 8, 5]
# Percentage of y=1: 48.0
# 0
# Error Unweighted: 0.424
# Error Huang: 0.376
# [1.         0.88679245]
# CUMULATIVE
# ringnorm
# [1.         1.17887375]
# [0.         0.34280778]
# 1
# Error Unweighted: 0.424
# Error Huang: 0.374
# [1.         0.88207547]
# CUMULATIVE
# ringnorm
# [1.         1.15350191]
# [0.         0.33432111]
# 2
# Error Unweighted: 0.424
# Error Huang: 0.38
# [1.         0.89622642]
# CUMULATIVE
# ringnorm
# [1.         1.12945471]
# [0.        0.3258043]
# 3
# Error Unweighted: 0.424
# Error Huang: 0.38
# [1.         0.89622642]
# CUMULATIVE
# ringnorm
# [1.         1.10590851]
# [0.         0.32088507]
# 4
# Error Unweighted: 0.424
# Error Huang: 0.38
# [1.         0.89622642]
# CUMULATIVE
# ringnorm
# [1.         1.07913832]
# [0.        0.3176208]
# 5
# Error Unweighted: 0.424
# Error Huang: 0.378
# [1.         0.89150943]
# CUMULATIVE
# ringnorm
# [1.         1.06066727]
# [0.         0.31377759]
# 6
# Error Unweighted: 0.424
# Error Huang: 0.38
# [1.         0.89622642]
# CUMULATIVE
# ringnorm
# [1.         1.04794925]
# [0.         0.31314017]
# 7
# Error Unweighted: 0.424
# Error Huang: 0.382
# [1.        0.9009434]
# CUMULATIVE
# ringnorm
# [1.         1.03580137]
# [0.         0.31130154]
# 8
# Error Unweighted: 0.424
# Error Huang: 0.378
# [1.         0.89150943]
# CUMULATIVE
# ringnorm
# [1.         1.02825525]
# [0.         0.31023392]
# 9
# Error Unweighted: 0.424
# Error Huang: 0.378
# [1.         0.89150943]
# CUMULATIVE
# ringnorm
# [1.         1.02057992]
# [0.         0.30653708]
# 10
# Error Unweighted: 0.424
# Error Huang: 0.378
# [1.         0.89150943]
# CUMULATIVE
# ringnorm
# [1.         1.01382312]
# [0.         0.30386513]
# 11
# Error Unweighted: 0.424
# Error Huang: 0.378
# [1.         0.89150943]
# CUMULATIVE
# ringnorm
# [1.        1.0065242]
# [0.         0.30235262]
# 12
# Error Unweighted: 0.424
# Error Huang: 0.38
# [1.         0.89622642]
# CUMULATIVE
# ringnorm
# [1.         1.00501296]
# [0.         0.30208756]
# 13
# Error Unweighted: 0.424
# Error Huang: 0.378
# [1.         0.89150943]
# CUMULATIVE
# ringnorm
# [1.        1.0018782]
# [0.         0.30182208]
# 14
# Error Unweighted: 0.424
# Error Huang: 0.38
# [1.         0.89622642]
# CUMULATIVE
# ringnorm
# [1.         0.99678245]
# [0.         0.29905992]
# 15
# Error Unweighted: 0.424
# Error Huang: 0.38
# [1.         0.89622642]
# CUMULATIVE
# ringnorm
# [1.         0.99359244]
# [0.         0.29654882]
# 16
# Error Unweighted: 0.424
# Error Huang: 0.38599999999999995
# [1.         0.91037736]
# CUMULATIVE
# ringnorm
# [1.         0.99384124]
# [0.         0.29611722]
# 17
# Error Unweighted: 0.424
# Error Huang: 0.39
# [1.         0.91981132]
# CUMULATIVE
# ringnorm
# [1.         0.99244204]
# [0.         0.29456323]
# 18
# Error Unweighted: 0.424
# Error Huang: 0.39
# [1.         0.91981132]
# CUMULATIVE
# ringnorm
# [1.         0.99331412]
# [0.         0.29422872]
# 19
# Error Unweighted: 0.424
# Error Huang: 0.39
# [1.         0.91981132]
# CUMULATIVE
# ringnorm
# [1.         0.99353382]
# [0.         0.29338484]
# 20
# Error Unweighted: 0.424
# Error Huang: 0.388
# [1.         0.91509434]
# CUMULATIVE
# ringnorm
# [1.         0.99520255]
# [0.         0.29201856]
# 21
# Error Unweighted: 0.424
# Error Huang: 0.388
# [1.         0.91509434]
# CUMULATIVE
# ringnorm
# [1.         0.99514652]
# [0.         0.29081765]
# 22
# Error Unweighted: 0.424
# Error Huang: 0.38599999999999995
# [1.         0.91037736]
# CUMULATIVE
# ringnorm
# [1.         0.99680774]
# [0.         0.29101296]
# 23
# Error Unweighted: 0.424
# Error Huang: 0.38599999999999995
# [1.         0.91037736]
# CUMULATIVE
# ringnorm
# [1.         0.99893182]
# [0.         0.29181992]
# 24
# Error Unweighted: 0.424
# Error Huang: 0.38599999999999995
# [1.         0.91037736]
# CUMULATIVE
# ringnorm
# [1.         1.00030145]
# [0.        0.2922829]
# 25
# Error Unweighted: 0.424
# Error Huang: 0.38599999999999995
# [1.         0.91037736]
# CUMULATIVE
# ringnorm
# [1.         1.00491462]
# [0.         0.29344182]
# 26
# Error Unweighted: 0.424
# Error Huang: 0.38599999999999995
# [1.         0.91037736]
# CUMULATIVE
# ringnorm
# [1.         1.00779413]
# [0.         0.29524083]
# 27
# Error Unweighted: 0.424
# Error Huang: 0.38599999999999995
# [1.         0.91037736]
# CUMULATIVE
# ringnorm
# [1.         1.01007064]
# [0.         0.29721296]
# 28
# Error Unweighted: 0.424
# Error Huang: 0.38599999999999995
# [1.         0.91037736]
# CUMULATIVE
# ringnorm
# [1.         1.01339537]
# [0.         0.29880038]
# 29
# Error Unweighted: 0.424
# Error Huang: 0.388
# [1.         0.91509434]
# CUMULATIVE
# ringnorm
# [1.        1.0153937]
# [0.         0.30088555]
# 30
# Error Unweighted: 0.424
# Error Huang: 0.39
# [1.         0.91981132]
# CUMULATIVE
# ringnorm
# [1.         1.01988404]
# [0.         0.30167494]
# [8, 4, 11, 0, 12]
# Percentage of y=1: 57.0
# 0
# Error Unweighted: 0.294
# Error Huang: 0.6240000000000001
# [1.         2.12244898]
# CUMULATIVE
# ringnorm
# [1.         1.18924271]
# [0.         0.35482693]
# 1
# Error Unweighted: 0.294
# Error Huang: 0.6099999999999999
# [1.         2.07482993]
# CUMULATIVE
# ringnorm
# [1.        1.1636264]
# [0.         0.34607488]
# 2
# Error Unweighted: 0.294
# Error Huang: 0.586
# [1.         1.99319728]
# CUMULATIVE
# ringnorm
# [1.         1.13894639]
# [0.         0.33628894]
# 3
# Error Unweighted: 0.294
# Error Huang: 0.564
# [1.         1.91836735]
# CUMULATIVE
# ringnorm
# [1.         1.11483663]
# [0.         0.33016623]
# 4
# Error Unweighted: 0.294
# Error Huang: 0.5459999999999999
# [1.         1.85714286]
# CUMULATIVE
# ringnorm
# [1.         1.08768782]
# [0.         0.32611781]
# 5
# Error Unweighted: 0.294
# Error Huang: 0.532
# [1.         1.80952381]
# CUMULATIVE
# ringnorm
# [1.         1.06889646]
# [0.         0.32166629]
# 6
# Error Unweighted: 0.294
# Error Huang: 0.518
# [1.         1.76190476]
# CUMULATIVE
# ringnorm
# [1.         1.05579491]
# [0.         0.32018607]
# 7
# Error Unweighted: 0.294
# Error Huang: 0.496
# [1.         1.68707483]
# CUMULATIVE
# ringnorm
# [1.         1.04295822]
# [0.         0.31694411]
# 8
# Error Unweighted: 0.294
# Error Huang: 0.48799999999999993
# [1.         1.65986395]
# CUMULATIVE
# ringnorm
# [1.       1.035196]
# [0.         0.31547284]
# 9
# Error Unweighted: 0.294
# Error Huang: 0.478
# [1.         1.62585034]
# CUMULATIVE
# ringnorm
# [1.         1.02723124]
# [0.         0.31131014]
# 10
# Error Unweighted: 0.294
# Error Huang: 0.46599999999999997
# [1.         1.58503401]
# CUMULATIVE
# ringnorm
# [1.         1.02010016]
# [0.         0.30800238]
# 11
# Error Unweighted: 0.294
# Error Huang: 0.4580000000000001
# [1.         1.55782313]
# CUMULATIVE
# ringnorm
# [1.         1.01258243]
# [0.         0.30613023]
# 12
# Error Unweighted: 0.294
# Error Huang: 0.444
# [1.         1.51020408]
# CUMULATIVE
# ringnorm
# [1.         1.01056452]
# [0.         0.30500466]
# 13
# Error Unweighted: 0.294
# Error Huang: 0.424
# [1.         1.44217687]
# CUMULATIVE
# ringnorm
# [1.         1.00671665]
# [0.         0.30364857]
# 14
# Error Unweighted: 0.294
# Error Huang: 0.41999999999999993
# [1.         1.42857143]
# CUMULATIVE
# ringnorm
# [1.         1.00152739]
# [0.         0.30079945]
# 15
# Error Unweighted: 0.294
# Error Huang: 0.40800000000000003
# [1.        1.3877551]
# CUMULATIVE
# ringnorm
# [1.         0.99792389]
# [0.         0.29776393]
# 16
# Error Unweighted: 0.294
# Error Huang: 0.4000000000000001
# [1.         1.36054422]
# CUMULATIVE
# ringnorm
# [1.         0.99787094]
# [0.         0.29695673]
# 17
# Error Unweighted: 0.294
# Error Huang: 0.39
# [1.         1.32653061]
# CUMULATIVE
# ringnorm
# [1.         0.99611335]
# [0.        0.2950035]
# 18
# Error Unweighted: 0.294
# ...
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         0.99906511]
# [0.         0.28931231]
# 17
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         0.99727314]
# [0.         0.28772191]
# 18
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         0.99805984]
# [0.        0.2873059]
# 19
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         0.99823672]
# [0.         0.28606366]
# 20
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         0.99949522]
# [0.         0.28449636]
# 21
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         0.99962309]
# [0.         0.28335235]
# 22
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         1.00154068]
# [0.         0.28371992]
# 23
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         1.00331147]
# [0.         0.28443949]
# 24
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         1.00456891]
# [0.         0.28482968]
# 25
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         1.00816752]
# [0.         0.28557206]
# 26
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         1.01074727]
# [0.         0.28739908]
# 27
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.        1.0132315]
# [0.         0.28936677]
# 28
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         1.01640389]
# [0.         0.29073935]
# 29
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         1.01822712]
# [0.         0.29263952]
# 30
# Error Unweighted: 0.41999999999999993
# Error Huang: 0.404
# [1.         0.96190476]
# CUMULATIVE
# ringnorm
# [1.         1.02212151]
# [0.         0.29334404]
# [0, 10, 9, 8, 14]
# Percentage of y=1: 52.0
# 0
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.023999999999999997
# [1.         0.14634146]
# CUMULATIVE
# ringnorm
# [1.         1.17699267]
# [0.         0.36066997]
# 1
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.020000000000000004
# [1.         0.12195122]
# CUMULATIVE
# ringnorm
# [1.         1.15128849]
# [0.         0.35340454]
# 2
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.016000000000000004
# [1.         0.09756098]
# CUMULATIVE
# ringnorm
# [1.         1.12679801]
# [0.         0.34378672]
# 3
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.016000000000000004
# [1.         0.09756098]
# CUMULATIVE
# ringnorm
# [1.         1.10343558]
# [0.         0.33692477]
# 4
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.016000000000000004
# [1.         0.09756098]
# CUMULATIVE
# ringnorm
# [1.        1.0777784]
# [0.         0.33237061]
# 5
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.014000000000000002
# [1.         0.08536585]
# CUMULATIVE
# ringnorm
# [1.         1.05954492]
# [0.         0.32754386]
# 6
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.011999999999999999
# [1.         0.07317073]
# CUMULATIVE
# ringnorm
# [1.         1.04692298]
# [0.        0.3256651]
# 7
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.008
# [1.         0.04878049]
# CUMULATIVE
# ringnorm
# [1.         1.03431176]
# [0.        0.3226848]
# 8
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.008
# [1.         0.04878049]
# CUMULATIVE
# ringnorm
# [1.         1.02688972]
# [0.         0.32093466]
# 9
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.008
# [1.         0.04878049]
# CUMULATIVE
# ringnorm
# [1.         1.01870328]
# [0.         0.31673519]
# 10
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.008
# [1.         0.04878049]
# CUMULATIVE
# ringnorm
# [1.         1.01125597]
# [0.         0.31335939]
# 11
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.008
# [1.         0.04878049]
# CUMULATIVE
# ringnorm
# [1.         1.00403915]
# [0.         0.31137714]
# 12
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.005999999999999999
# [1.         0.03658537]
# CUMULATIVE
# ringnorm
# [1.         1.00183589]
# [0.         0.31080897]
# 13
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.005999999999999999
# [1.         0.03658537]
# CUMULATIVE
# ringnorm
# [1.         0.99821341]
# [0.         0.30959857]
# 14
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.005999999999999999
# [1.         0.03658537]
# CUMULATIVE
# ringnorm
# [1.         0.99306069]
# [0.         0.30705765]
# 15
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.005999999999999999
# [1.         0.03658537]
# CUMULATIVE
# ringnorm
# [1.         0.98927986]
# [0.         0.30434355]
# 16
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.005999999999999999
# [1.         0.03658537]
# CUMULATIVE
# ringnorm
# [1.         0.98924389]
# [0.         0.30365077]
# 17
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.005999999999999999
# [1.         0.03658537]
# CUMULATIVE
# ringnorm
# [1.        0.9874702]
# [0.         0.30209374]
# 18
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.005999999999999999
# [1.         0.03658537]
# CUMULATIVE
# ringnorm
# [1.         0.98824887]
# [0.        0.3017269]
# 19
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.005999999999999999
# [1.         0.03658537]
# CUMULATIVE
# ringnorm
# [1.         0.98842395]
# [0.         0.30056208]
# 20
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.004000000000000001
# [1.         0.02439024]
# CUMULATIVE
# ringnorm
# [1.         0.98954517]
# [0.         0.29952566]
# 21
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.004000000000000001
# [1.         0.02439024]
# CUMULATIVE
# ringnorm
# [1.         0.98967174]
# [0.         0.29845459]
# 22
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.004000000000000001
# [1.         0.02439024]
# CUMULATIVE
# ringnorm
# [1.         0.99156976]
# [0.         0.29886329]
# 23
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.004000000000000001
# [1.         0.02439024]
# CUMULATIVE
# ringnorm
# [1.         0.99332247]
# [0.         0.29959792]
# 24
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.004000000000000001
# [1.         0.02439024]
# CUMULATIVE
# ringnorm
# [1.         0.99456709]
# [0.         0.30000608]
# 25
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.004000000000000001
# [1.         0.02439024]
# CUMULATIVE
# ringnorm
# [1.         0.99812897]
# [0.         0.30082248]
# 26
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.004000000000000001
# [1.         0.02439024]
# CUMULATIVE
# ringnorm
# [1.        1.0006824]
# [0.         0.30262459]
# 27
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.004000000000000001
# [1.         0.02439024]
# CUMULATIVE
# ringnorm
# [1.         1.00314128]
# [0.         0.30455626]
# 28
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.004000000000000001
# [1.         0.02439024]
# CUMULATIVE
# ringnorm
# [1.        1.0062813]
# [0.         0.30595114]
# 29
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.004000000000000001
# [1.         0.02439024]
# CUMULATIVE
# ringnorm
# [1.         1.00808593]
# [0.         0.30779844]
# 30
# Error Unweighted: 0.16400000000000003
# Error Huang: 0.002
# [1.         0.01219512]
# CUMULATIVE
# ringnorm
# [1.         1.01181613]
# [0.         0.30898887]
# [0, 16, 2, 15, 13]
# Percentage of y=1: 51.0
# 0
# Error Unweighted: 0.342
# Error Huang: 0.38399999999999995
# [1.         1.12280702]
# CUMULATIVE
# ringnorm
# [1.         1.17644534]
# [0.         0.35888469]
# 1
# Error Unweighted: 0.342
# Error Huang: 0.376
# [1.        1.0994152]
# CUMULATIVE
# ringnorm
# [1.         1.15076451]
# [0.        0.3516534]
# 2
# Error Unweighted: 0.342
# Error Huang: 0.366
# [1.         1.07017544]
# CUMULATIVE
# ringnorm
# [1.         1.12622607]
# [0.         0.34209288]
# 3
# Error Unweighted: 0.342
# Error Huang: 0.356
# [1.         1.04093567]
# CUMULATIVE
# ringnorm
# [1.         1.10280427]
# [0.         0.33527707]
# 4
# Error Unweighted: 0.342
# Error Huang: 0.354
# [1.         1.03508772]
# CUMULATIVE
# ringnorm
# [1.         1.07734719]
# [0.         0.33071526]
# 5
# Error Unweighted: 0.342
# Error Huang: 0.3439999999999999
# [1.         1.00584795]
# CUMULATIVE
# ringnorm
# [1.         1.05900253]
# [0.         0.32592963]
# 6
# Error Unweighted: 0.342
# Error Huang: 0.3400000000000001
# [1.         0.99415205]
# CUMULATIVE
# ringnorm
# [1.         1.04638994]
# [0.         0.32405912]
# 7
# Error Unweighted: 0.342
# Error Huang: 0.334
# [1.         0.97660819]
# CUMULATIVE
# ringnorm
# [1.         1.03372889]
# [0.         0.32110279]
# 8
# Error Unweighted: 0.342
# Error Huang: 0.334
# [1.         0.97660819]
# CUMULATIVE
# ringnorm
# [1.         1.02638183]
# [0.         0.31934924]
# 9
# Error Unweighted: 0.342
# Error Huang: 0.3320000000000001
# [1.         0.97076023]
# CUMULATIVE
# ringnorm
# [1.         1.01821901]
# [0.         0.31516792]
# 10
# Error Unweighted: 0.342
# Error Huang: 0.334
# [1.         0.97660819]
# CUMULATIVE
# ringnorm
# [1.         1.01090599]
# [0.       0.311792]
# 11
# Error Unweighted: 0.342
# Error Huang: 0.33
# [1.         0.96491228]
# CUMULATIVE
# ringnorm
# [1.         1.00364393]
# [0.         0.30982524]
# 12
# Error Unweighted: 0.342
# Error Huang: 0.322
# [1.         0.94152047]
# CUMULATIVE
# ringnorm
# [1.         1.00122664]
# [0.         0.30929406]
# 13
# Error Unweighted: 0.342
# Error Huang: 0.324
# [1.         0.94736842]
# CUMULATIVE
# ringnorm
# [1.         0.99769982]
# [0.         0.30807292]
# 14
# Error Unweighted: 0.342
# Error Huang: 0.324
# [1.         0.94736842]
# CUMULATIVE
# ringnorm
# [1.         0.99259916]
# [0.         0.30553709]
# 15
# Error Unweighted: 0.342
# Error Huang: 0.312
# [1.        0.9122807]
# CUMULATIVE
# ringnorm
# [1.         0.98850209]
# [0.         0.30290043]
# 16
# Error Unweighted: 0.342
# Error Huang: 0.316
# [1.         0.92397661]
# CUMULATIVE
# ringnorm
# [1.         0.98858462]
# [0.         0.30218377]
# 17
# Error Unweighted: 0.342
# Error Huang: 0.31
# [1.         0.90643275]
# CUMULATIVE
# ringnorm
# [1.         0.98665164]
# [0.         0.30067335]
# 18
# Error Unweighted: 0.342
# Error Huang: 0.318
# [1.         0.92982456]
# CUMULATIVE
# ringnorm
# [1.         0.98765873]
# [0.       0.300256]
# 19
# Error Unweighted: 0.342
# Error Huang: 0.318
# [1.         0.92982456]
# CUMULATIVE
# ringnorm
# [1.         0.98783204]
# [0.         0.29909764]
# 20
# Error Unweighted: 0.342
# Error Huang: 0.324
# [1.         0.94736842]
# CUMULATIVE
# ringnorm
# [1.         0.98911915]
# [0.         0.29803891]
# 21
# Error Unweighted: 0.342
# Error Huang: 0.32599999999999996
# [1.         0.95321637]
# CUMULATIVE
# ringnorm
# [1.        0.9893035]
# [0.         0.29696579]
# 22
# Error Unweighted: 0.342
# Error Huang: 0.322
# [1.         0.94152047]
# CUMULATIVE
# ringnorm
# [1.         0.99106421]
# [0.         0.29739216]
# 23
# Error Unweighted: 0.342
# Error Huang: 0.314
# [1.         0.91812865]
# CUMULATIVE
# ringnorm
# [1.         0.99256294]
# [0.         0.29817577]
# 24
# Error Unweighted: 0.342
# Error Huang: 0.316
# [1.         0.92397661]
# CUMULATIVE
# ringnorm
# [1.         0.99385405]
# [0.        0.2985705]
# 25
# Error Unweighted: 0.342
# Error Huang: 0.312
# [1.        0.9122807]
# CUMULATIVE
# ringnorm
# [1.         0.99726182]
# [0.        0.2994224]
# 26
# Error Unweighted: 0.342
# Error Huang: 0.30599999999999994
# [1.         0.89473684]
# CUMULATIVE
# ringnorm
# [1.         0.99961224]
# [0.         0.30127863]
# 27
# Error Unweighted: 0.342
# Error Huang: 0.308
# [1.        0.9005848]
# CUMULATIVE
# ringnorm
# [1.         1.00210536]
# [0.         0.30318768]
# 28
# Error Unweighted: 0.342
# Error Huang: 0.312
# [1.        0.9122807]
# CUMULATIVE
# ringnorm
# [1.        1.0053318]
# [0.        0.3045471]
# 29
# Error Unweighted: 0.342
# Error Huang: 0.316
# [1.         0.92397661]
# CUMULATIVE
# ringnorm
# [1.         1.00723634]
# [0.         0.30635543]
# 30
# Error Unweighted: 0.342
# Error Huang: 0.318
# [1.         0.92982456]
# CUMULATIVE
# ringnorm
# [1.         1.01098794]
# [0.         0.30753367]
# [5, 19, 4, 0, 18]
# Percentage of y=1: 42.0
# 0
# Error Unweighted: 0.456
# Error Huang: 0.352
# [1.         0.77192982]
# CUMULATIVE
# ringnorm
# [1.         1.17240019]
# [0.         0.35934691]
# 1
# Error Unweighted: 0.456
# Error Huang: 0.352
# [1.         0.77192982]
# CUMULATIVE
# ringnorm
# [1.         1.14697617]
# [0.         0.35191521]
# 2
# Error Unweighted: 0.456
# Error Huang: 0.35
# [1.         0.76754386]
# CUMULATIVE
# ringnorm
# [1.         1.12263924]
# [0.         0.34224396]
# 3
# Error Unweighted: 0.456
# Error Huang: 0.352
# [1.         0.77192982]
# CUMULATIVE
# ringnorm
# [1.         1.09949552]
# [0.       0.335217]
# 4
# Error Unweighted: 0.456
# Error Huang: 0.35
# [1.         0.76754386]
# CUMULATIVE
# ringnorm
# [1.         1.07424915]
# [0.         0.33049817]
# 5
# Error Unweighted: 0.456
# Error Huang: 0.346
# [1.         0.75877193]
# CUMULATIVE
# ringnorm
# [1.         1.05600022]
# [0.         0.32566884]
# 6
# Error Unweighted: 0.456
# Error Huang: 0.35
# [1.         0.76754386]
# CUMULATIVE
# ringnorm
# [1.         1.04360148]
# [0.         0.32362624]
# 7
# Error Unweighted: 0.456
# Error Huang: 0.346
# [1.         0.75877193]
# CUMULATIVE
# ringnorm
# [1.         1.03097932]
# [0.         0.32066241]
# 8
# Error Unweighted: 0.456
# Error Huang: 0.35
# [1.         0.76754386]
# CUMULATIVE
# ringnorm
# [1.         1.02379345]
# [0.         0.31879048]
# 9
# Error Unweighted: 0.456
# Error Huang: 0.352
# [1.         0.77192982]
# CUMULATIVE
# ringnorm
# [1.         1.01575612]
# [0.         0.31454416]
# 10
# Error Unweighted: 0.456
# Error Huang: 0.35
# [1.         0.76754386]
# CUMULATIVE
# ringnorm
# [1.         1.00847237]
# [0.         0.31117268]
# 11
# Error Unweighted: 0.456
# Error Huang: 0.352
# [1.         0.77192982]
# CUMULATIVE
# ringnorm
# [1.         1.00132679]
# [0.         0.30913315]
# 12
# Error Unweighted: 0.456
# Error Huang: 0.354
# [1.         0.77631579]
# CUMULATIVE
# ringnorm
# [1.         0.99897753]
# [0.         0.30855628]
# 13
# Error Unweighted: 0.456
# Error Huang: 0.354
# [1.         0.77631579]
# CUMULATIVE
# ringnorm
# [1.         0.99548598]
# [0.         0.30731913]
# 14
# Error Unweighted: 0.456
# Error Huang: 0.356
# [1.         0.78070175]
# CUMULATIVE
# ringnorm
# [1.         0.99048018]
# [0.         0.30473578]
# 15
# Error Unweighted: 0.456
# Error Huang: 0.356
# [1.         0.78070175]
# CUMULATIVE
# ringnorm
# [1.         0.98642408]
# [0.         0.30209051]
# 16
# Error Unweighted: 0.456
# Error Huang: 0.354
# [1.         0.77631579]
# CUMULATIVE
# ringnorm
# [1.         0.98646193]
# [0.         0.30140994]
# 17
# Error Unweighted: 0.456
# Error Huang: 0.356
# [1.         0.78070175]
# CUMULATIVE
# ringnorm
# [1.         0.98459214]
# [0.         0.29986719]
# 18
# Error Unweighted: 0.456
# Error Huang: 0.356
# [1.         0.78070175]
# CUMULATIVE
# ringnorm
# [1.         0.98558916]
# [0.         0.29945978]
# 19
# Error Unweighted: 0.456
# Error Huang: 0.358
# [1.         0.78508772]
# CUMULATIVE
# ringnorm
# [1.        0.9858046]
# [0.         0.29828132]
# 20
# Error Unweighted: 0.456
# Error Huang: 0.356
# [1.         0.78070175]
# CUMULATIVE
# ringnorm
# [1.         0.98703497]
# [0.         0.29726916]
# 21
# Error Unweighted: 0.456
# Error Huang: 0.354
# [1.         0.77631579]
# CUMULATIVE
# ringnorm
# [1.         0.98717362]
# [0.         0.29623622]
# 22
# Error Unweighted: 0.456
# Error Huang: 0.356
# [1.         0.78070175]
# CUMULATIVE
# ringnorm
# [1.         0.98896059]
# [0.         0.29664082]
# 23
# Error Unweighted: 0.456
# Error Huang: 0.354
# [1.         0.77631579]
# CUMULATIVE
# ringnorm
# [1.         0.99040047]
# [0.         0.29746034]
# 24
# Error Unweighted: 0.456
# Error Huang: 0.352
# [1.         0.77192982]
# CUMULATIVE
# ringnorm
# [1.         0.99163481]
# [0.        0.2978934]
# 25
# Error Unweighted: 0.456
# Error Huang: 0.352
# [1.         0.77192982]
# CUMULATIVE
# ringnorm
# [1.        0.9950085]
# [0.         0.29876396]
# 26
# Error Unweighted: 0.456
# Error Huang: 0.352
# [1.         0.77192982]
# CUMULATIVE
# ringnorm
# [1.         0.99733542]
# [0.         0.30062324]
# 27
# Error Unweighted: 0.456
# Error Huang: 0.354
# [1.         0.77631579]
# CUMULATIVE
# ringnorm
# [1.         0.99984746]
# [0.         0.30250331]
# 28
# Error Unweighted: 0.456
# Error Huang: 0.354
# [1.         0.77631579]
# CUMULATIVE
# ringnorm
# [1.         1.00304164]
# [0.        0.3038761]
# 29
# Error Unweighted: 0.456
# Error Huang: 0.358
# [1.         0.78508772]
# CUMULATIVE
# ringnorm
# [1.         1.00501485]
# [0.         0.30562015]
# 30
# Error Unweighted: 0.456
# Error Huang: 0.358
# [1.         0.78508772]
# CUMULATIVE
# ringnorm
# [1.         1.00872893]
# [0.         0.30681654]
