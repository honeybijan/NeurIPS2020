# %%
import numpy as np
from numpy import genfromtxt
from sklearn import svm
from sklearn.metrics import accuracy_score
import random
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
import numpy.linalg as LA
import scipy
import sys
from cvxopt import matrix, solvers
import scipy.io as sio
def V_matrix_Huang(T,X,n_t):
  l = len(X)
  m = len(T)
  V = np.identity(l)
  P = matrix(gram_matrix(X))
  K = Kernel.gaussian(1)
  sum_T = [0 for i in range(l)]
  for i in range(l):
    for t in range(m):
      sum_T[i]+=K(T[t],X[i])
    sum_T[i] = -1*l/m*sum_T[i]  
  q = matrix(sum_T)
  G = [[0]*l for i in range(2*l+2)]
  for i in range(l):
    G[i][i] = 1
    G[i+1][i] = -1
  for j in range(l):
    G[2*l][j] = 1
    G[2*l+1][j] = -1
 
  G = matrix(np.array(G),tc ='d')
  B = 10
  eps = 1-1/np.sqrt(l)
  h = [0 for i in range(2*l+2)]
  for i in range(l):
    h[i] = B
  h[2*l] = l+l*eps
  h[2*l+1] = l-l*eps   
  h = matrix(h)
  sol = solvers.qp(P,q,G,h)
  solution = np.array(sol['x'])
  diagonal = [solution[i][0] for i in range(l)]
  V = np.diag(diagonal)
  return V 

def V_matrix_new(T,X,n_t):
  l = len(X)
  V_3 = np.identity(l) # our V
  for i in range(l):
    for j in range(l):
      V_3[i,j] = 0
      for t in T:
        if t >= np.maximum(X[i],X[j]):
          V_3[i,j]+= 1
      V_3[i,j] = V_3[i,j]/n_t 
  return V_3    
def unif_kernel(x,X,h):
  n = len(X)
  val = 0
  for i in range(n):
    if np.abs((x-X[i])/h) <=1:
      val+= 0.5
    
  q = val/(n*h)
  return q
def gauss_kernel(x,X,h):
  n = len(X)
  val = 0
  for i in range(n):
    val+=1/(np.sqrt(2*np.pi))*(np.exp(-((x-X[i])/h)**2/2))
  q = val/(n*h)
  return q
def V_matrix_Shimodaira(T,X,n_t,h):
  l = len(X)
  V_1 = np.identity(l)
  a = 0.3
  for i in range(l):
    l_1 = gauss_kernel(X[i],T,h)
    l_0 = gauss_kernel(X[i],X,h)
    V_1[i,i] = l_1/l_0
  return V_1
def V_matrix_Sugiyama(T,X,n_t,h,tau):
  l = len(X)
  V_1 = np.identity(l)
  for i in range(l):
    l_1 = gauss_kernel(X[i],T,h)
    l_0 = gauss_kernel(X[i],X,h)
    V_1[i,i] = (l_1/l_0)**tau
  return V_1 
def V_matrix_Makoto(T,X,n_t,h,a):
  l = len(X)
  V_1 = np.identity(l)
  for i in range(l):
    l_1 = gauss_kernel(X[i],T,h)
    l_0 = gauss_kernel(X[i],X,h)
    V_1[i,i] = l_1/(a*l_0+(1-a)*l_1)
  return V_1  
"""Using direct closed form solution for conditional probability distribution from Vapnik's paper for VSVM problem

---


P(y=1|x)  = A^T\mathcal{K}+c

---


A = A_b - cA_c

---


A_b  

---


A_c 

---


c 

---


\mathcal{K} = [...K(x,x_i)...]^T 

---
U = [---K(x_i,x_j)--] where x_i, x_j are the ith and jth sample form training data and K is the kernel.

---

Y= (y_1, y_2, ...., y_n) training labels
"""

def test_methods(T,X,Y,V_1,V_2,V_3,V_4):
  U = gram_matrix(X)# get the gram matrix for the given training set X
  g = 0.1  
  A_1,c_1 = A_estimate(V_1,U,Y,g)
  A_2,c_2 = A_estimate(V_2,U,Y,g)
  A_3,c_3 = A_estimate(V_3,U,Y,g)
  A_4,c_4 = A_estimate(V_4,U,Y,g)
  p_1 = []
  p_2 = []
  p_3 = []
  p_4 = []
  T = np.sort(T)
  p_exp = np.array([1/(1+np.exp(5*t))for t in T])
  for t in range(len(T)):
    U_l = style_K(X,T[t]) #U_l = # kernel for the test set
    p_1.append(p_estimate(A_1,c_1,U_l))
    p_2.append(p_estimate(A_2,c_2,U_l))
    p_3.append(p_estimate(A_3,c_3,U_l))
    p_4.append(p_estimate(A_4,c_4,U_l))
  p_1 = np.array(p_1)
  p_2 = np.array(p_2)
  p_3 = np.array(p_3)
  p_4 = np.array(p_4)
  error_1 = LA.norm(p_exp-p_1)/len(T)
  error_2 = LA.norm(p_exp-p_2)/len(T)
  error_3 = LA.norm(p_exp-p_3)/len(T)
  error_4 = LA.norm(p_exp-p_4)/len(T)
  return error_1,error_2,error_3,error_4
def test_methods_review(T,X,Y,V_5):
  U = gram_matrix(X)# get the gram matrix for the given training set X
  g = 0.1  
  A_5, c_5 = A_estimate(V_5,U,Y,g)
  p_5 = []
  T = np.sort(T)
  p_exp = np.array([1/(1+np.exp(5*t))for t in T])
  for t in range(len(T)):
    U_l = style_K(X,T[t]) #U_l = # kernel for the test set
    p_5.append(p_estimate(A_5,c_5,U_l))
  p_5 = np.array(p_5)
  error_5 = LA.norm(p_exp-p_5)/len(T)
  return error_5 
#Estimate of A and c
def A_estimate(V,U,Y,g):
  l = V.shape[0]
  I = np.identity(l)
  O = np.ones((l,1))
  a_1 = np.matmul(V,U)
  a_2 = np.matmul(V,Y.reshape(l,1))
  a_3 = np.matmul(V,O)
  T = np.linalg.inv(a_1+g*I) # g:regularization constant
  A_b = np.matmul(T,a_2).reshape(l,1) 
  A_c = np.matmul(T,a_3).reshape(l,1) 
  c_1 = np.matmul(O.transpose(),np.matmul(a_1,A_b)-a_2) 
  c_2 = np.matmul(O.transpose(),np.matmul(a_1,A_c)-a_3)
  c = c_1/c_2 
  A = A_b - c[0,0]*A_c
  return A,c
#Conditional probability estimate for a given x
def p_estimate(A,c,U_l):
  p = np.matmul(A.transpose(),U_l)+c
  return p[0,0] 

def gram_matrix(X):
   l = X.shape[0]
   U = np.zeros((l,l))
   K = Kernel.gaussian(1)         
   for i in range(l):
     for j in range(l):
       U[i,j] = K(X[i],X[j])
   return U
def style_K(X,t):
   l = X.shape[0]
   U_l = np.zeros((l,1))
   K = Kernel.gaussian(1)
   for i in range(l):
     U_l[i] = K(t,X[i])    
   return U_l  
class SVMTrainer(object):
    def __init__(self, kernel, c):
        self._kernel = kernel
        self._c = c

    def train(self, X, y):
        """Given the training features X with labels y, returns a SVM
        predictor representing the trained SVM.
        """
        lagrange_multipliers = self._compute_multipliers(X, y)
        return self._construct_predictor(X, y, lagrange_multipliers)

    def _gram_matrix(self, X):
        n_samples, n_features = X.shape
        K = np.zeros((n_samples, n_samples))
        # TODO(tulloch) - vectorize
        for i, x_i in enumerate(X):
            for j, x_j in enumerate(X):
                K[i, j] = self._kernel(x_i, x_j)
        return K

    def _construct_predictor(self, X, y, lagrange_multipliers):
        support_vector_indices = \
            lagrange_multipliers > MIN_SUPPORT_VECTOR_MULTIPLIER

        support_multipliers = lagrange_multipliers[support_vector_indices]
        support_vectors = X[support_vector_indices]
        support_vector_labels = y[support_vector_indices]

        # http://www.cs.cmu.edu/~guestrin/Class/10701-S07/Slides/kernels.pdf
        # bias = y_k - \sum z_i y_i  K(x_k, x_i)
        # Thus we can just predict an example with bias of zero, and
        # compute error.
        bias = np.mean(
            [y_k - SVMPredictor(
                kernel=self._kernel,
                bias=0.0,
                weights=support_multipliers,
                support_vectors=support_vectors,
                support_vector_labels=support_vector_labels).predict(x_k)
             for (y_k, x_k) in zip(support_vector_labels, support_vectors)])

        return SVMPredictor(
            kernel=self._kernel,
            bias=bias,
            weights=support_multipliers,
            support_vectors=support_vectors,
            support_vector_labels=support_vector_labels)

    def _compute_multipliers(self, X, y):
        n_samples, n_features = X.shape

        K = self._gram_matrix(X)
        # Solves
        # min 1/2 x^T P x + q^T x
        # s.t.
        #  Gx \coneleq h
        #  Ax = b

        P = cvxopt.matrix(np.outer(y, y) * K)
        q = cvxopt.matrix(-1 * np.ones(n_samples))

        # -a_i \leq 0
        # TODO(tulloch) - modify G, h so that we have a soft-margin classifier
        G_std = cvxopt.matrix(np.diag(np.ones(n_samples) * -1))
        h_std = cvxopt.matrix(np.zeros(n_samples))

        # a_i \leq c
        G_slack = cvxopt.matrix(np.diag(np.ones(n_samples)))
        h_slack = cvxopt.matrix(np.ones(n_samples) * self._c)

        G = cvxopt.matrix(np.vstack((G_std, G_slack)))
        h = cvxopt.matrix(np.vstack((h_std, h_slack)))

        A = cvxopt.matrix(y, (1, n_samples))
        b = cvxopt.matrix(0.0)

        solution = cvxopt.solvers.qp(P, q, G, h, A, b)

        # Lagrange multipliers
        return np.ravel(solution['x'])
class SVMPredictor(object):
    def __init__(self,
                 kernel,
                 bias,
                 weights,
                 support_vectors,
                 support_vector_labels):
        self._kernel = kernel
        self._bias = bias
        self._weights = weights
        self._support_vectors = support_vectors
        self._support_vector_labels = support_vector_labels

    def predict(self, x):
        """
        Computes the SVM prediction on the given features x.
        """
        result = self._bias
        for z_i, x_i, y_i in zip(self._weights,
                                 self._support_vectors,
                                 self._support_vector_labels):
            result += z_i * y_i * self._kernel(x_i, x)
        return np.sign(result).item()   
import numpy.linalg as la


class Kernel(object):
    """Implements list of kernels from
    http://en.wikipedia.org/wiki/Support_vector_machine
    """
    @staticmethod
    def linear():
        def f(x, y):
            return np.inner(x, y)
        return f

    @staticmethod
    def gaussian(sigma):
        def f(x, y):
            exponent = -np.sqrt(la.norm(x-y)**2  / (2 * sigma ** 2))
            return np.exp(exponent)
        return f

    @staticmethod
    def _polykernel(dimension, offset):
        def f(x, y):
            return (offset + np.dot(x, y)) ** dimension
        return f

    @staticmethod
    def inhomogenous_polynomial(dimension):
        return Kernel._polykernel(dimension=dimension, offset=1.0)

    @staticmethod
    def homogenous_polynomial(dimension):
        return Kernel._polykernel(dimension=dimension, offset=0.0)

    @staticmethod
    def hyperbolic_tangent(kappa, c):
        def f(x, y):
            return np.tanh(kappa * np.dot(x, y) + c)
        return f
"""We start by sampling points randomly from -1 to 1"""
def random_labels(X, prob):
  y = []
  for x in X:
    if random.random() < prob(x):
      y.append(1)
    else:
      y.append(0)
  return np.array(y)
def check_methods():
  number_of_points = 100 #Number of training points
  l = number_of_points
  X = (2 * (np.random.rand(number_of_points))) - 1
  balance = 0.5 #training data balance
  for i in range(number_of_points):
      num = np.random.rand(1)
      if num < balance:
        X[i]=np.random.rand(1)-1
      else:
        X[i]=np.random.rand(1)   
      X = np.array(X)  
      X = np.squeeze(X)

      

  p = lambda x: 1/(1 + np.exp(5* x)) # the probability of x being labeled y=1
  Y = random_labels(X, p)
  print(Y.shape)
  xs = [-1 + (i/20) for i in range(41)]
  true_p = [p(x) for x in xs]
  plt.plot(xs, true_p, label='p(y=1|x)')
  plt.plot(X, Y, '.', label='Data')
  plt.legend(loc='best')
  plt.show()
  l = number_of_points
  V_1 = np.identity(l) # without Vapnik
  V_2 = np.identity(l) # Vapnik 
  for i in range(l):
    for j in range(l):
      V_2[i,j] = 1-np.maximum(X[i],X[j])

  """We label the points according a Sigmoid function"""

  n_t_array = [i for i in range(100,550,100)] # number of test points
  h = 2
  E_1 = []
  E_2 = []
  E_3 = []
  E_4 = []
  balance = 0.7 #test data balance
  tau = [0.5]
  alpha = [0.5]
  E_5 = [[] for ta in tau]
  E_6 = [[] for alph in alpha]
  E_7 = []
  D = []
  D.append(X)
  D.append(Y)
  ctr = 1
  
  for n_t in n_t_array:
    T = (2 * (np.random.rand(n_t))) - 1
    for i in range(n_t):
      num = np.random.rand(1)
      if num < balance:
        T[i]=np.random.rand(1)-1
      else:
        T[i]=np.random.rand(1)   
    T = np.array(T)  
    T = np.squeeze(T)
    D.append(T)
    V_3= V_matrix_new(T,X,n_t) 
    V_4 = V_matrix_Shimodaira(T,X,n_t,h) 
    error_1,error_2,error_3, error_4 = test_methods(T,X,Y,V_1,V_2,V_3,V_4)  
    E_1.append(error_1)
    E_2.append(error_2)
    E_3.append(error_3)
    E_4.append(error_4)
    for ta in range(len(tau)):
      V_5 = V_matrix_Sugiyama(T,X,n_t,h,tau[ta])
      error_5 = test_methods_review(T,X,Y,V_5)
      E_5[ta].append(error_5)
    for alph in range(len(alpha)):
      V_6 = V_matrix_Makoto(T,X,n_t,h,alpha[alph])  
      error_6 = test_methods_review(T,X,Y,V_6)
      E_6[alph].append(error_6)
    V_7 = V_matrix_Huang(T,X,n_t)
    error_7 = test_methods_review(T,X,Y,V_7) 
    E_7.append(error_7) 
    ctr+=1  
  return E_1,E_2,E_3,E_4,E_5[0],E_6[0],E_7,D  
M = 50
E_big_1 = [[] for i in range(M)]  
E_big_2 = [[] for i in range(M)]  
E_big_3 = [[] for i in range(M)]  
E_big_4 = [[] for i in range(M)]  
E_big_5 = [[] for i in range(M)]  
E_big_6 = [[] for i in range(M)]  
E_big_7 = [[] for i in range(M)]  
n_t_array = [i for i in range(100,550,100)]
U = {}
for i in range(M):
  E_big_1[i], E_big_2[i], E_big_3[i],E_big_4[i],E_big_5[i],E_big_6[i],E_big_7[i],D = check_methods()
  U['pass_'+str(i)] = D
sio.savemat('data.mat',U)
E_big_1 = np.array([np.array(E_big_1[i]) for i in range(M)])  
E_big_2 = np.array([np.array(E_big_2[i]) for i in range(M)])  
E_big_3 = np.array([np.array(E_big_3[i]) for i in range(M)])  
E_big_4 = np.array([np.array(E_big_4[i]) for i in range(M)])  
E_big_5 = np.array([np.array(E_big_5[i]) for i in range(M)])  
E_big_6 = np.array([np.array(E_big_6[i]) for i in range(M)])  
E_big_7 = np.array([np.array(E_big_7[i]) for i in range(M)])   
E_1_mean = []
E_2_mean = []
E_3_mean = []
E_4_mean = []
E_5_mean = []
E_6_mean = []
E_7_mean = []
E_1_std = []
E_2_std = []
E_3_std = []
E_4_std = []
E_5_std = []
E_6_std = []
E_7_std = []
for i in range(len(n_t_array)):
  E_1_mean.append(np.mean(E_big_1[:,i]))
  E_2_mean.append(np.mean(E_big_2[:,i]))
  E_3_mean.append(np.mean(E_big_3[:,i]))
  E_4_mean.append(np.mean(E_big_4[:,i]))
  E_5_mean.append(np.mean(E_big_5[:,i]))
  E_6_mean.append(np.mean(E_big_6[:,i]))
  E_7_mean.append(np.mean(E_big_7[:,i]))
  E_1_std.append(np.std(E_big_1[:,i]))
  E_2_std.append(np.std(E_big_2[:,i]))
  E_3_std.append(np.std(E_big_3[:,i]))
  E_4_std.append(np.std(E_big_4[:,i]))
  E_5_std.append(np.std(E_big_5[:,i]))
  E_6_std.append(np.std(E_big_6[:,i]))
  E_7_std.append(np.std(E_big_7[:,i]))
plt.errorbar(n_t_array,E_1_mean,E_1_std,marker='x', label='V = I',capsize = 5) # No Vapnik
plt.errorbar(n_t_array,E_2_mean,E_2_std,marker= '+',label='V in Vapnik',capsize = 5) # Vapnik V
plt.errorbar(n_t_array, E_3_mean,E_3_std,marker='d', label = 'Proposed V',capsize = 5) #Our V
plt.errorbar(n_t_array, E_4_mean,E_4_std,marker='*', label = 'Shimodaira',capsize = 5) #Shimodaira
plt.errorbar(n_t_array, E_7_mean,E_7_std,marker='d', label = 'Huang',capsize = 5) #Huang
plt.errorbar(n_t_array, E_5_mean,E_5_std,marker='*', label = 'Sugiyama',capsize = 5) #Sugiyama
plt.errorbar(n_t_array, E_6_mean,E_6_std,marker='d', label = 'Makoto',capsize = 5) #Makoto
plt.legend(loc='best')
plt.xlabel('Number of test points')
plt.ylabel('Normalized L2-error')
plt.grid()
plt.savefig('Comparison_5_7_new.png')
"""(1) Stability of estimated probability curve is controlled by number of training points.
Result: Both Vapnik and our method are more stable than classical SVM. 

---

(2) Test distribution is not uniform and is instead chosen to be "biased" towards one half, meaning the probability that a point in the test set distribution falls in the range [0,1] is given by balance. For unifrom distribution in [-1,1], balance = 0.5. If we want probability of range [0,1] to be 0.7, balance = 0.3.  

---

(3) The empirical estimate of test distribution becomes better with more test data n_t. Our method performs better than Vapnik  when the L2-error is compared for the conditional probability estimates.
"""
# Out:
# (100,)
#      pcost       dcost       gap    pres   dres
#  0: -3
E_big_8 = [[] for i in range(M)]
for i in range(M):
    XYT = datas['pass_'+str(i)]
    for j in range(5):
        T = np.squeeze(XYT[0,j+2])
        X = np.squeeze(XYT[0,0])
        Y = np.squeeze(XYT[0,1])
        V = Vs[i,j]
        error_8 = test_methods_review(T,X,Y,V) 
        E_big_8[i].append(error_8) 
E_big_8 = np.array([np.array(E_big_8[i]) for i in range(M)])   
print(E_big_8)
E_8_mean = []
E_8_std = []
for i in range(5):
      E_8_mean.append(np.mean(E_big_8[:,i]))
      E_8_std.append(np.std(E_big_8[:,i]))
# Out:
# [[0.01573104 0.01007086 0.01019826 0.00852003 0.00695503]
#  [0.01415156 0.01186318 0.00884967 0.00653615 0.00606188]
#  [0.01044799 0.00725322 0.00617684 0.00517301 0.00454613]
#  [0.01010893 0.006894   0.00563481 0.00488236 0.00409656]
#  [0.0080998  0.00674878 0.00587876 0.0049353  0.0045336 ]
#  [0.00883031 0.00567188 0.00514661 0.00452754 0.00380427]
#  [0.00723532 0.00521597 0.00441106 0.00341279 0.00280978]
#  [0.00872538 0.0069811  0.00555937 0.00561882 0.00449176]
#  [0.01516326 0.01112445 0.00950374 0.00770427 0.00738845]
#  [0.00750102 0.00522584 0.00445722 0.00369928 0.00335401]
#  [0.01074537 0.00673811 0.00575719 0.00438701 0.00402824]
#  [0.01200846 0.00970499 0.00777065 0.00643088 0.00591103]
#  [0.00974586 0.00838582 0.00626374 0.00587512 0.00490661]
#  [0.01250919 0.00864295 0.00675487 0.0067067  0.00623512]
#  [0.0063719  0.00546527 0.00423526 0.00357794 0.00318822]
#  [0.01127012 0.00720589 0.00642299 0.0053901  0.00484911]
#  [0.00940921 0.00623187 0.0048634  0.00422625 0.00360219]
#  [0.01991396 0.01338157 0.01049324 0.00973653 0.0084295 ]
#  [0.00925887 0.00752726 0.00572464 0.00449777 0.00465574]
#  [0.00808075 0.00547348 0.0044547  0.00442038 0.00384675]
#  [0.01202369 0.00881253 0.00703477 0.00625113 0.00574929]
#  [0.01049849 0.00745194 0.00587238 0.00472619 0.00419966]
#  [0.00704257 0.00507443 0.00396199 0.00365394 0.00313564]
#  [0.01234378 0.00815856 0.00684529 0.00565541 0.00559186]
#  [0.00802719 0.00628142 0.00493572 0.00476605 0.00415456]
#  [0.01659346 0.01206746 0.01035233 0.00857119 0.0070578 ]
#  [0.01163831 0.00897831 0.00637678 0.00644116 0.00507219]
#  [0.00795496 0.00637722 0.00570429 0.00451653 0.00417808]
#  [0.01472441 0.01242844 0.01054058 0.00901214 0.00823009]
#  [0.00968871 0.00709508 0.00579304 0.00510549 0.00467061]
#  [0.00913991 0.00640134 0.0046136  0.00444548 0.00372688]
#  [0.01578751 0.01146098 0.00928343 0.00767767 0.00742198]
#  [0.01043593 0.00700708 0.00547618 0.00483434 0.00445852]
#  [0.00986338 0.00784344 0.00577262 0.00531477 0.00464344]
#  [0.00790711 0.00452843 0.00444929 0.00391614 0.00354772]
#  [0.00789512 0.0057677  0.00480885 0.00430476 0.00356528]
#  [0.00942985 0.00644209 0.00525038 0.00497009 0.00408525]
#  [0.01377142 0.01037728 0.00733783 0.00631696 0.0052676 ]
#  [0.01318928 0.00849853 0.00705334 0.00616564 0.00547547]
#  [0.01130205 0.00789697 0.00611107 0.00606917 0.00489173]
#  [0.01234676 0.0083084  0.00696652 0.00492411 0.00524824]
#  [0.01028571 0.00690311 0.00601086 0.00516719 0.00438475]
#  [0.01435412 0.01068273 0.00841383 0.00726511 0.00682189]
#  [0.01138927 0.00915173 0.00863859 0.00636436 0.0055051 ]
#  [0.00830827 0.00485917 0.00443613 0.00368297 0.00342269]
#  [0.00924271 0.00717811 0.00555023 0.00431036 0.00436963]
#  [0.01191602 0.0087889  0.00719245 0.00640626 0.00561265]
#  [0.0080837  0.00492072 0.00390416 0.00348561 0.00327248]
#  [0.01039432 0.0083242  0.0063075  0.00548768 0.00447154]
#  [0.00985871 0.00765169 0.00559987 0.00485666 0.00455863]]

# %%
#uLSIF - data_final.mat is generated in MATLAB by running uLSIF matlab function, It comprises of uLSIF importance weights.
datas = sio.loadmat('../uLSIF/data_final')
M = 50
Vs = datas['V']
E_big_9 = [[] for i in range(M)]
for i in range(M):
    XYT = datas['pass_'+str(i)]
    for j in range(5):
        T = np.squeeze(XYT[0,j+2])
        X = np.squeeze(XYT[0,0])
        Y = np.squeeze(XYT[0,1])
        V = Vs[i,j]
        error_9 = test_methods_review(T,X,Y,V) 
        E_big_9[i].append(error_9) 
E_big_9 = np.array([np.array(E_big_9[i]) for i in range(M)])   
print(E_big_9)
E_9_mean = []
E_9_std = []
for i in range(5):
      E_9_mean.append(np.mean(E_big_9[:,i]))
      E_9_std.append(np.std(E_big_9[:,i]))
# Out:
# [[0.01559333 0.01012107 0.01012431 0.00856403 0.0069188 ]
#  [0.01510629 0.01354884 0.00864316 0.00653039 0.00683245]
#  [0.01106133 0.00725522 0.00763126 0.00514791 0.0045136 ]
#  [0.01050742 0.0071069  0.00542748 0.00497035 0.00438547]
#  [0.00779262 0.00767127 0.00639392 0.00578979 0.00206855]
#  [0.00929513 0.00560569 0.00492906 0.00435662 0.0037095 ]
#  [0.00628448 0.00511284 0.0042965  0.00487603 0.00276822]
#  [0.01157845 0.0076031  0.00610909 0.00604753 0.00435632]
#  [0.01533136 0.010949   0.00937531 0.00542818 0.00727102]
#  [0.00748321 0.00470357 0.00562782 0.00350851 0.00306559]
#  [0.01092137 0.00670731 0.00602828 0.00439771 0.00401777]
#  [0.01196155 0.00974743 0.0078352  0.00637602 0.00579414]
#  [0.00924452 0.00830263 0.0063957  0.00680219 0.00489827]
#  [0.01281848 0.00862755 0.00371093 0.00685162 0.00648218]
#  [0.00621065 0.00546161 0.00323002 0.00383235 0.00303716]
#  [0.01398017 0.00662724 0.00609046 0.00508104 0.00447782]
#  [0.01076379 0.00647886 0.00463067 0.00424059 0.00345235]
#  [0.02049374 0.01351354 0.01075528 0.00985146 0.00847086]
#  [0.00715112 0.00730784 0.00583296 0.00336961 0.00466303]
#  [0.01225052 0.00799196 0.00448348 0.00467954 0.00372919]
#  [0.01202397 0.00876151 0.00702283 0.006217   0.00630012]
#  [0.01047467 0.00751724 0.0060731  0.00440917 0.00453926]
#  [0.00728994 0.00522188 0.00402419 0.00369974 0.00327984]
#  [0.0081027  0.00832464 0.01290914 0.00579051 0.00184227]
#  [0.00795845 0.00586879 0.00493976 0.00454699 0.00418227]
#  [0.01689929 0.01204576 0.01024359 0.00852965 0.00694607]
#  [0.01286499 0.00985331 0.00456282 0.00722061 0.00520225]
#  [0.00792526 0.0065169  0.00569377 0.00422758 0.00403859]
#  [0.01450457 0.01311647 0.01493481 0.00900924 0.00834679]
#  [0.00979229 0.00413544 0.00574559 0.00506618 0.00300727]
#  [0.00911625 0.00659851 0.00465525 0.00502779 0.00373843]
#  [0.02484078 0.01147812 0.00985051 0.00669913 0.00744842]
#  [0.01150341 0.00743028 0.00263676 0.0040119  0.00469174]
#  [0.01020778 0.00789746 0.00444458 0.0052978  0.00285891]
#  [0.00815302 0.00492892 0.00436934 0.00396066 0.00352512]
#  [0.0075671  0.00442807 0.00384558 0.0040207  0.00298322]
#  [0.00973646 0.00646609 0.00576927 0.00495065 0.00411843]
#  [0.01287774 0.01042695 0.00700808 0.00620229 0.0052948 ]
#  [0.01778954 0.00843899 0.00866264 0.00625024 0.00546964]
#  [0.01567125 0.00721815 0.00569381 0.00571434 0.00499683]
#  [0.01227281 0.00512267 0.00694161 0.00498375 0.00547978]
#  [0.01132089 0.00943043 0.0058976  0.00571249 0.00435057]
#  [0.01454441 0.01028656 0.00836691 0.00774692 0.00655562]
#  [0.0161765  0.00926074 0.00853098 0.00638003 0.00555375]
#  [0.01367429 0.00480492 0.00452491 0.00370919 0.00394224]
#  [0.0106453  0.00971044 0.00426357 0.00435656 0.00430899]
#  [0.00732242 0.00910958 0.00738322 0.00618714 0.00675211]
#  [0.01197015 0.00489405 0.00383865 0.00358171 0.00326382]
#  [0.01009537 0.00818584 0.00632393 0.00536223 0.00439272]
#  [0.00905861 0.00786814 0.00548334 0.00685834 0.00456577]]

# %%
plt.errorbar(n_t_array,E_1_mean,E_1_std,marker='x', label='V = I',capsize = 5) # No Vapnik
plt.errorbar(n_t_array,E_2_mean,E_2_std,marker= '+',label='V in Vapnik',capsize = 5) # Vapnik V
plt.errorbar(n_t_array, E_3_mean,E_3_std,marker='d', label = 'Proposed V',capsize = 5) #Our V
plt.errorbar(n_t_array, E_4_mean,E_4_std,marker='*', label = 'Shimodaira',capsize = 5) #Shimodaira
plt.errorbar(n_t_array, E_7_mean,E_7_std,marker='d', label = 'Huang',capsize = 5) #Huang
plt.errorbar(n_t_array, E_5_mean,E_5_std,marker='*', label = 'Sugiyama',capsize = 5) #Sugiyama
plt.errorbar(n_t_array, E_6_mean,E_6_std,marker='d', label = 'Makoto',capsize = 5) #Makoto
plt.errorbar(n_t_array, E_8_mean,E_8_std,marker='*', label = 'KLIEP',capsize = 5) #Sugiyama
plt.errorbar(n_t_array, E_9_mean,E_9_std,marker='d', label = 'uLSIF',capsize = 5) #Kanamori
plt.legend(loc='best')
plt.xlabel('Number of test points')
plt.ylabel('Normalized L2-error')
plt.grid()
plt.savefig('Comparison_5_7_new.png')
